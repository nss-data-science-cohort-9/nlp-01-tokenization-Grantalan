# %% [markdown]
# # Tokenization
#
# In this notebook, you'll see how to use the NLTK library to tokenize and normalize text data.

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/grantalan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/grantalan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/grantalan/nltk_data...
# True

# %%
conda install NLTK
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# doneieving notices: -
# Channels:
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: /
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - nltk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.5.14  |       hca03da5_0         108 KB
#     certifi-2026.5.20          |  py313hca03da5_0         131 KB
#     nltk-3.9.4                 |  py313h7eb115d_0         4.0 MB
#     ------------------------------------------------------------
#                                            Total:         4.2 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/noarch::ca-certificates-2~ --> pkgs/main/osx-arm64::ca-certificates-2026.5.14-hca03da5_0
#   certifi            conda-forge/noarch::certifi-2026.4.22~ --> pkgs/main/osx-arm64::certifi-2026.5.20-py313hca03da5_0
#   nltk                                3.9.1-py313h0ef513f_0 --> 3.9.4-py313h7eb115d_0
#
#
#
# Downloading and Extracting Packages:
# nltk-3.9.4           | 4.0 MB    |                                       |   0%
# certifi-2026.5.20    | 131 KB    |                                       |   0%
#
# nltk-3.9.4           | 4.0 MB    | 2                                     |   1%
# certifi-2026.5.20    | 131 KB    | ####5                                 |  12%
#
# ca-certificates-2026 | 108 KB    | #####4                                |  15%
#
# ca-certificates-2026 | 108 KB    | ##################################### | 100%
# certifi-2026.5.20    | 131 KB    | ##################################### | 100%
#
# ca-certificates-2026 | 108 KB    | ##################################### | 100%
#
#
#
#
# donearing transaction: |
# donefying transaction: -
# doneuting transaction: |
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter

from nltk.tokenize import sent_tokenize, word_tokenize, regexp_tokenize
from nltk.corpus import stopwords

from nltk.stem import PorterStemmer, WordNetLemmatizer

# %% [markdown]
# In this notebook, we'll be working with the full text of Moby Dick.

# %%
with open('../data/moby_dick.txt', encoding = 'utf-8') as fi:
    moby = fi.read()

# %%
moby[:1000]
# Out:
# '  ETYMOLOGY.\n\n\n  (Supplied by a Late Consumptive Usher to a Grammar School.)\n\n  The pale Usher—threadbare in coat, heart, body, and brain; I see him\n  now. He was ever dusting his old lexicons and grammars, with a queer\n  handkerchief, mockingly embellished with all the gay flags of all the\n  known nations of the world. He loved to dust his old grammars; it\n  somehow mildly reminded him of his mortality.\n\n  “While you take in hand to school others, and to teach them by what\n  name a whale-fish is to be called in our tongue, leaving out, through\n  ignorance, the letter H, which almost alone maketh up the\n  signification of the word, you deliver that which is not true.”\n  —_Hackluyt._\n\n  “WHALE. * * * Sw. and Dan. _hval_. This animal is named from\n  roundness or rolling; for in Dan. _hvalt_ is arched or vaulted.”\n  —_Webster’s Dictionary._\n\n  “WHALE. * * * It is more immediately from the Dut. and Ger. _Wallen_;\n  A.S. _Walw-ian_, to roll, to wallow.” —_Richardson’s Dictionary._\n\n\n  חו,  '

# %% [markdown]
# First, let's split into sentences. For this, we can use the `sent_tokenize` function.

# %%
sentences = sent_tokenize(moby)

# %%
print(sentences[1000])
# Out:
# Because no man can ever feel his own identity aright
# except his eyes be closed; as if darkness were indeed the proper
# element of our essences, though light be more congenial to our clayey
# part.

# %% [markdown]
# If we want to split into tokens, we can utilize one of nltk's word tokenizers.

# %%
i = 1000
print(sentences[i])
word_tokenize(sentences[i])
# Out:
# Because no man can ever feel his own identity aright
# except his eyes be closed; as if darkness were indeed the proper
# element of our essences, though light be more congenial to our clayey
# part.
# ['Because',
#  'no',
#  'man',
#  'can',
#  'ever',
#  'feel',
#  'his',
#  'own',
#  'identity',
#  'aright',
#  'except',
#  'his',
#  'eyes',
#  'be',
#  'closed',
#  ';',
#  'as',
#  'if',
#  'darkness',
#  'were',
#  'indeed',
#  'the',
#  'proper',
#  'element',
#  'of',
#  'our',
#  'essences',
#  ',',
#  'though',
#  'light',
#  'be',
#  'more',
#  'congenial',
#  'to',
#  'our',
#  'clayey',
#  'part',
#  '.']

# %% [markdown]
# Notice how `word_tokenize` counts punctuation marks as tokens. If we want to be more specific in what we count as a token, we can make use of the `regexp_tokenize` function which allows us to specify a regular expression pattern to define a token.
#
# For example, we can look for word characters using `\w`. This will match one or more of any letter or digit.

# %%
regexp_tokenize(sentences[1000], r'\w+')
# Out:
# ['Because',
#  'no',
#  'man',
#  'can',
#  'ever',
#  'feel',
#  'his',
#  'own',
#  'identity',
#  'aright',
#  'except',
#  'his',
#  'eyes',
#  'be',
#  'closed',
#  'as',
#  'if',
#  'darkness',
#  'were',
#  'indeed',
#  'the',
#  'proper',
#  'element',
#  'of',
#  'our',
#  'essences',
#  'though',
#  'light',
#  'be',
#  'more',
#  'congenial',
#  'to',
#  'our',
#  'clayey',
#  'part']

# %% [markdown]
# Let's add a couple of other types of characters to catch and then count up the most frequent tokens using the `Counter` class. This will create a dictionary whose keys are the tokens and values are the frequency counts.

# %%
moby_counter = Counter(regexp_tokenize(moby, r'[-\'\w]+'))

# %%
moby_counter['whale']
# Out:
# 790

# %%
moby_counter['Ishmael']
# Out:
# 19

# %% [markdown]
# Let's see how large a vocabulary we have.

# %%
len(moby_counter)
# Out:
# 20302

# %% [markdown]
# Or how many total words.

# %%
sum(moby_counter.values())
# Out:
# 216124

# %% [markdown]
# We can also see the most common words.

# %%
moby_counter.most_common()
# Out:
# [('the', 13796),
#  ('of', 6557),
#  ('and', 6044),
#  ('a', 4567),
#  ('to', 4532),
#  ('in', 3924),
#  ('that', 2981),
#  ('his', 2472),
#  ('it', 2210),
#  ('I', 2120),
#  ('s', 1779),
#  ('is', 1697),
#  ('with', 1662),
#  ('he', 1662),
#  ('was', 1633),
#  ('as', 1620),
#  ('all', 1450),
#  ('for', 1420),
#  ('this', 1280),
#  ('at', 1234),
#  ('by', 1141),
#  ('but', 1113),
#  ('not', 1104),
#  ('him', 1060),
#  ('from', 1059),
#  ('be', 1027),
#  ('on', 1014),
#  ('so', 915),
#  ('one', 883),
#  ('you', 841),
#  ('whale', 790),
#  ('had', 767),
#  ('have', 760),
#  ('there', 716),
#  ('But', 705),
#  ('or', 701),
#  ('were', 679),
#  ('now', 646),
#  ('which', 642),
#  ('me', 625),
#  ('their', 614),
#  ('The', 612),
#  ('they', 587),
#  ('are', 586),
#  ('an', 582),
#  ('some', 580),
#  ('then', 571),
#  ('my', 564),
#  ('like', 558),
#  ('when', 554),
#  ('upon', 539),
#  ('into', 521),
#  ('out', 519),
#  ('Ahab', 505),
#  ('up', 501),
#  ('more', 501),
#  ('no', 486),
#  ('man', 481),
#  ('them', 474),
#  ('ship', 462),
#  ('ye', 461),
#  ('what', 442),
#  ('old', 429),
#  ('if', 421),
#  ('would', 419),
#  ('been', 415),
#  ('we', 413),
#  ('other', 413),
#  ('over', 399),
#  ('these', 381),
#  ('will', 377),
#  ('its', 373),
#  ('And', 369),
#  ('sea', 365),
#  ('only', 360),
#  ('down', 357),
#  ('such', 336),
#  ('though', 335),
#  ('her', 329),
#  ('any', 321),
#  ('who', 318),
#  ('time', 317),
#  ('very', 311),
#  ('It', 310),
#  ('than', 309),
#  ('long', 306),
#  ('about', 305),
#  ('said', 304),
#  ('still', 299),
#  ('yet', 299),
#  ('those', 297),
#  ('before', 295),
#  ('great', 291),
#  ('has', 287),
#  ('boat', 284),
#  ('Whale', 284),
#  ('t', 284),
#  ('seemed', 283),
#  ('must', 282),
#  ('two', 279),
#  ('most', 277),
#  ('last', 276),
#  ('here', 271),
#  ('head', 271),
#  ('do', 266),
#  ('way', 265),
#  ('Stubb', 255),
#  ('again', 254),
#  ('see', 253),
#  ('Queequeg', 252),
#  ('after', 248),
#  ('little', 247),
#  ('did', 246),
#  ('round', 241),
#  ('your', 240),
#  ('whales', 238),
#  ('say', 237),
#  ('In', 237),
#  ('thou', 232),
#  ('men', 232),
#  ('three', 231),
#  ('He', 230),
#  ('may', 230),
#  ('us', 228),
#  ('through', 227),
#  ('every', 222),
#  ('being', 219),
#  ('much', 218),
#  ('can', 218),
#  ('could', 215),
#  ('while', 215),
#  ('Captain', 214),
#  ('off', 211),
#  ('first', 211),
#  ('same', 210),
#  ('own', 205),
#  ('himself', 203),
#  ('our', 199),
#  ('hand', 198),
#  ('Starbuck', 198),
#  ('For', 197),
#  ('never', 196),
#  ('ever', 191),
#  ('where', 191),
#  ('side', 189),
#  ('thing', 188),
#  ('how', 187),
#  ('almost', 186),
#  ('go', 183),
#  ('might', 183),
#  ('too', 182),
#  ('should', 181),
#  ('good', 180),
#  ('even', 179),
#  ('made', 177),
#  ('What', 174),
#  ('away', 172),
#  ('Pequod', 172),
#  ('world', 167),
#  ('well', 166),
#  ('water', 166),
#  ('seen', 161),
#  ('many', 161),
#  ('deck', 160),
#  ('among', 159),
#  ('white', 159),
#  ('day', 158),
#  ('eyes', 156),
#  ('cried', 156),
#  ('far', 155),
#  ('without', 154),
#  ('sort', 152),
#  ('know', 151),
#  ('come', 150),
#  ('CHAPTER', 149),
#  ('thought', 148),
#  ('part', 148),
#  ('A', 147),
#  ('So', 147),
#  ('There', 147),
#  ('back', 146),
#  ('once', 144),
#  ('boats', 143),
#  ('sir', 143),
#  ('Now', 139),
#  ('crew', 139),
#  ('air', 138),
#  ('life', 136),
#  ('whole', 136),
#  ('look', 135),
#  ('Sperm', 135),
#  ('against', 133),
#  ('things', 132),
#  ('night', 131),
#  ('God', 130),
#  ('came', 130),
#  ('thee', 129),
#  ('each', 127),
#  ('feet', 126),
#  ('till', 122),
#  ('small', 122),
#  ('hands', 122),
#  ('As', 120),
#  ('let', 120),
#  ('Oh', 119),
#  ('something', 119),
#  ('take', 118),
#  ('between', 118),
#  ('tell', 118),
#  ('both', 118),
#  ('under', 116),
#  ('found', 115),
#  ('saw', 114),
#  ('called', 113),
#  ('soon', 113),
#  ('ll', 113),
#  ('times', 112),
#  ('full', 111),
#  ('think', 111),
#  ('just', 111),
#  ('place', 111),
#  ('body', 110),
#  ('heard', 110),
#  ('along', 110),
#  ('make', 109),
#  ('captain', 109),
#  ('line', 108),
#  ('This', 107),
#  ('towards', 107),
#  ('thus', 107),
#  ('another', 106),
#  ('fish', 105),
#  ('moment', 105),
#  ('thy', 105),
#  ('Flask', 105),
#  ('poor', 104),
#  ('she', 104),
#  ('sight', 104),
#  ('don', 103),
#  ('nothing', 102),
#  ('sperm', 102),
#  ('whaling', 101),
#  ('No', 98),
#  ('went', 97),
#  ('strange', 95),
#  ('end', 95),
#  ('face', 94),
#  ('high', 93),
#  ('years', 92),
#  ('few', 92),
#  ('get', 92),
#  ('sun', 92),
#  ('right', 91),
#  ('voyage', 91),
#  ('dead', 90),
#  ('half', 90),
#  ('does', 89),
#  ('stood', 89),
#  ('White', 89),
#  ('heart', 88),
#  ('also', 88),
#  ('certain', 87),
#  ('Nantucket', 87),
#  ('Aye', 87),
#  ('whose', 86),
#  ('am', 86),
#  ('hold', 86),
#  ('leg', 86),
#  ('That', 85),
#  ('matter', 85),
#  ('seem', 85),
#  ('shall', 84),
#  ('Jonah', 84),
#  ('seems', 84),
#  ('arm', 84),
#  ('itself', 84),
#  ('At', 84),
#  ('eye', 82),
#  ('perhaps', 82),
#  ('soul', 82),
#  ('indeed', 82),
#  ('Moby', 82),
#  ('Dick', 82),
#  ('sometimes', 81),
#  ('known', 80),
#  ('however', 80),
#  ('seas', 80),
#  ('nor', 80),
#  ('always', 80),
#  ('wild', 80),
#  ('days', 79),
#  ('sail', 79),
#  ('mind', 79),
#  ('going', 79),
#  ('black', 79),
#  ('present', 79),
#  ('within', 78),
#  ('length', 78),
#  ('They', 78),
#  ('oil', 78),
#  ('large', 78),
#  ('ships', 77),
#  ('stand', 77),
#  ('instant', 77),
#  ('hard', 77),
#  ('Bildad', 77),
#  ('word', 76),
#  ('whether', 76),
#  ('tail', 76),
#  ('standing', 76),
#  ('Nor', 76),
#  ('least', 75),
#  ('harpooneer', 75),
#  ('young', 75),
#  ('iron', 75),
#  ('beneath', 74),
#  ('enough', 74),
#  ('light', 74),
#  ('done', 74),
#  ('true', 73),
#  ('land', 73),
#  ('vast', 73),
#  ('living', 73),
#  ('set', 73),
#  ('because', 73),
#  ('Peleg', 73),
#  ('put', 72),
#  ('harpoon', 72),
#  ('bed', 72),
#  ('cabin', 72),
#  ('give', 71),
#  ('mate', 71),
#  ('why', 71),
#  ('Pip', 71),
#  ('whalemen', 70),
#  ('near', 69),
#  ('open', 69),
#  ('cannot', 69),
#  ('name', 68),
#  ('four', 68),
#  ('wind', 68),
#  ('myself', 68),
#  ('rather', 68),
#  ('morning', 68),
#  ('often', 68),
#  ('case', 67),
#  ('How', 67),
#  ('lay', 67),
#  ('aye', 67),
#  ('point', 66),
#  ('left', 66),
#  ('business', 66),
#  ('ere', 66),
#  ('turned', 66),
#  ('keep', 66),
#  ('waters', 66),
#  ('deep', 65),
#  ('fire', 65),
#  ('Leviathan', 64),
#  ('together', 64),
#  ('order', 64),
#  ('general', 64),
#  ('reason', 64),
#  ('looked', 64),
#  ('ocean', 63),
#  ('since', 63),
#  ('Mr', 63),
#  ('board', 63),
#  ('best', 62),
#  ('having', 62),
#  ('To', 61),
#  ('hear', 60),
#  ('If', 60),
#  ('death', 60),
#  ('better', 60),
#  ('mouth', 59),
#  ('work', 59),
#  ('themselves', 59),
#  ('With', 59),
#  ('further', 59),
#  ('live', 59),
#  ('gone', 58),
#  ('Then', 58),
#  ('lower', 57),
#  ('feel', 56),
#  ('Indian', 56),
#  ('peculiar', 56),
#  ('home', 56),
#  ('Well', 56),
#  ('fine', 56),
#  ('chase', 56),
#  ('dark', 56),
#  ('therefore', 56),
#  ('find', 55),
#  ('goes', 55),
#  ('harpooneers', 55),
#  ('looking', 55),
#  ('All', 55),
#  ('entire', 55),
#  ('above', 54),
#  ('turn', 54),
#  ('jaw', 54),
#  ('short', 54),
#  ('second', 54),
#  ('His', 54),
#  ('Tashtego', 54),
#  ('aloft', 53),
#  ('vessel', 53),
#  ('began', 53),
#  ('comes', 53),
#  ('curious', 53),
#  ('blood', 52),
#  ('craft', 52),
#  ('forth', 52),
#  ('savage', 52),
#  ('bottom', 52),
#  ('When', 52),
#  ('call', 52),
#  ('taken', 51),
#  ('By', 51),
#  ('close', 51),
#  ('run', 51),
#  ('d', 51),
#  ('less', 51),
#  ('turning', 51),
#  ('broad', 51),
#  ('rest', 51),
#  ('ivory', 51),
#  ('fishery', 51),
#  ('behind', 50),
#  ('hundred', 50),
#  ('Right', 50),
#  ('thousand', 50),
#  ('Look', 50),
#  ('taking', 50),
#  ('sailors', 50),
#  ('_', 49),
#  ('coming', 49),
#  ('Here', 49),
#  ('sharks', 49),
#  ('slowly', 49),
#  ('particular', 49),
#  ('Yes', 49),
#  ('Though', 49),
#  ('took', 49),
#  ('devil', 48),
#  ('waves', 48),
#  ('New', 48),
#  ('Why', 48),
#  ('used', 48),
#  ('stranger', 48),
#  ('bows', 48),
#  ('mighty', 47),
#  ('stern', 47),
#  ('We', 47),
#  ('Not', 47),
#  ('forward', 47),
#  ('story', 47),
#  ('common', 47),
#  ('kept', 47),
#  ('You', 47),
#  ('below', 47),
#  ('earth', 46),
#  ('view', 46),
#  ('cut', 46),
#  ('told', 46),
#  ('voice', 46),
#  ('speak', 46),
#  ('green', 46),
#  ('fellow', 46),
#  ('English', 46),
#  ('On', 46),
#  ('sailor', 46),
#  ('else', 46),
#  ('broken', 46),
#  ('mark', 46),
#  ('got', 46),
#  ('next', 46),
#  ('several', 46),
#  ('spout', 46),
#  ('touching', 45),
#  ('monster', 45),
#  ('bones', 45),
#  ('lost', 45),
#  ('sat', 45),
#  ('struck', 45),
#  ('rope', 45),
#  ('straight', 45),
#  ('Yet', 45),
#  ('ten', 45),
#  ('sleep', 45),
#  ('suddenly', 45),
#  ('mine', 45),
#  ('fact', 45),
#  ('fast', 45),
#  ('queer', 44),
#  ('whatever', 44),
#  ('Lord', 44),
#  ('teeth', 44),
#  ('noble', 44),
#  ('chance', 44),
#  ('caught', 44),
#  ('form', 44),
#  ('wide', 44),
#  ('sure', 44),
#  ('especially', 44),
#  ('says', 44),
#  ('room', 44),
#  ('whaleman', 44),
#  ('means', 44),
#  ('somehow', 43),
#  ('whom', 43),
#  ('knew', 43),
#  ('nigh', 43),
#  ('Who', 43),
#  ('grand', 43),
#  ('rolled', 43),
#  ('watch', 43),
#  ('heads', 43),
#  ('mere', 42),
#  ('making', 42),
#  ('people', 42),
#  ('hours', 42),
#  ('door', 42),
#  ('seamen', 42),
#  ('em', 42),
#  ('running', 42),
#  ('sudden', 42),
#  ('creature', 42),
#  ('surface', 42),
#  ('calm', 41),
#  ('lance', 41),
#  ('blue', 41),
#  ('quite', 41),
#  ('cook', 41),
#  ('anything', 41),
#  ('passed', 41),
#  ('parts', 41),
#  ('sharp', 41),
#  ('felt', 41),
#  ('course', 41),
#  ('sound', 41),
#  ('wondrous', 41),
#  ('wake', 40),
#  ('mortal', 40),
#  ('boy', 40),
#  ('carpenter', 40),
#  ('saying', 40),
#  ('mates', 40),
#  ('brow', 40),
#  ('Steelkilt', 40),
#  ('Thou', 39),
#  ('clear', 39),
#  ('art', 39),
#  ('plainly', 39),
#  ('either', 39),
#  ('distance', 39),
#  ('bow', 39),
#  ('object', 39),
#  ('mass', 39),
#  ('mean', 39),
#  ('purpose', 39),
#  ('hour', 39),
#  ('makes', 39),
#  ('leaving', 38),
#  ('alone', 38),
#  ('brought', 38),
#  ('Let', 38),
#  ('fixed', 38),
#  ('Some', 38),
#  ('single', 38),
#  ('various', 38),
#  ('sailed', 38),
#  ('ready', 38),
#  ('cry', 38),
#  ('darted', 38),
#  ('concerning', 38),
#  ('gave', 38),
#  ('others', 37),
#  ('placed', 37),
#  ('heaven', 37),
#  ('around', 37),
#  ('manner', 37),
#  ('new', 37),
#  ('famous', 37),
#  ('plain', 37),
#  ('forehead', 37),
#  ('five', 37),
#  ('help', 37),
#  ('held', 37),
#  ('ve', 37),
#  ('hat', 37),
#  ('power', 37),
#  ('aspect', 37),
#  ('oh', 37),
#  ('sails', 37),
#  ('gentlemen', 37),
#  ('pull', 37),
#  ('Greenland', 36),
#  ('ago', 36),
#  ('fell', 36),
#  ('bulwarks', 36),
#  ('easy', 36),
#  ('bone', 36),
#  ('unknown', 36),
#  ('flukes', 36),
#  ('top', 36),
#  ('use', 36),
#  ('given', 36),
#  ('ground', 36),
#  ('oars', 36),
#  ('book', 35),
#  ('coast', 35),
#  ('previous', 35),
#  ('legs', 35),
#  ('sign', 35),
#  ('suppose', 35),
#  ('human', 35),
#  ('mad', 35),
#  ('Don', 35),
#  ('gold', 35),
#  ('st', 35),
#  ('brain', 34),
#  ('nature', 34),
#  ('pipe', 34),
#  ('mast-head', 34),
#  ('American', 34),
#  ('shot', 34),
#  ('forecastle', 34),
#  ('Such', 34),
#  ('Cape', 34),
#  ('middle', 34),
#  ('holding', 34),
#  ('thoughts', 34),
#  ('heavy', 34),
#  ('arms', 34),
#  ('turns', 34),
#  ('remained', 34),
#  ('Daggoo', 34),
#  ('strong', 33),
#  ('fifty', 33),
#  ('killed', 33),
#  ('creatures', 33),
#  ('ashore', 33),
#  ('account', 33),
#  ('Pacific', 33),
#  ('nearly', 33),
#  ('coffin', 33),
#  ('rigging', 33),
#  ('boys', 33),
#  ('idea', 33),
#  ('house', 33),
#  ('low', 33),
#  ('company', 33),
#  ('hammock', 33),
#  ('none', 33),
#  ('completely', 33),
#  ('skeleton', 33),
#  ('sailing', 33),
#  ('rolling', 32),
#  ('bulk', 32),
#  ('doubt', 32),
#  ('fear', 32),
#  ('passage', 32),
#  ('Do', 32),
#  ('bear', 32),
#  ('red', 32),
#  ('lines', 32),
#  ('table', 32),
#  ('want', 32),
#  ('wonder', 32),
#  ('skin', 32),
#  ('drawing', 32),
#  ('show', 32),
#  ('proper', 32),
#  ('helm', 32),
#  ('intervals', 32),
#  ('SAILOR', 32),
#  ('generally', 31),
#  ('miles', 31),
#  ('species', 31),
#  ('mast-heads', 31),
#  ('quick', 31),
#  ('darkness', 31),
#  ('jet', 31),
#  ('leviathan', 31),
#  ('visible', 31),
#  ('planks', 31),
#  ('weather', 31),
#  ('fair', 31),
#  ('hardly', 31),
#  ('sky', 31),
#  ('substance', 31),
#  ('across', 31),
#  ('aft', 31),
#  ('nose', 31),
#  ('except', 31),
#  ('natural', 31),
#  ('While', 30),
#  ('fresh', 30),
#  ('possible', 30),
#  ('upper', 30),
#  ('Besides', 30),
#  ('act', 30),
#  ('really', 30),
#  ('soft', 30),
#  ('won', 30),
#  ('truth', 30),
#  ('carried', 30),
#  ('cast', 30),
#  ('die', 30),
#  ('hull', 30),
#  ('instances', 30),
#  ('de', 30),
#  ('altogether', 29),
#  ('swimming', 29),
#  ('huge', 29),
#  ('jaws', 29),
#  ('steel', 29),
#  ('entirely', 29),
#  ('late', 29),
#  ('possibly', 29),
#  ('smoke', 29),
#  ('vain', 29),
#  ('unless', 29),
#  ('mast', 29),
#  ('cold', 29),
#  ('foot', 29),
#  ('tossed', 29),
#  ('final', 29),
#  ('harpoons', 29),
#  ('stands', 29),
#  ('mariners', 29),
#  ('Come', 29),
#  ('touch', 29),
#  ('wood', 29),
#  ('question', 29),
#  ('pass', 29),
#  ('strangely', 29),
#  ('hammer', 29),
#  ('rising', 29),
#  ('hoisted', 29),
#  ('ancient', 28),
#  ('strike', 28),
#  ('One', 28),
#  ('Whales', 28),
#  ('King', 28),
#  ('try', 28),
#  ('fishermen', 28),
#  ('free', 28),
#  ('Sir', 28),
#  ('pretty', 28),
#  ('Where', 28),
#  ('gale', 28),
#  ('knows', 28),
#  ('mild', 28),
#  ('considering', 28),
#  ('astern', 28),
#  ('already', 28),
#  ('words', 28),
#  ('hung', 28),
#  ('become', 28),
#  ('feeling', 28),
#  ('person', 28),
#  ('third', 28),
#  ('glance', 28),
#  ('O', 28),
#  ('start', 28),
#  ('leeward', 28),
#  ('Parsee', 28),
#  ('hearts', 27),
#  ('sides', 27),
#  ('lie', 27),
#  ('kind', 27),
#  ('precisely', 27),
#  ('leaning', 27),
#  ('quarter-deck', 27),
#  ('scene', 27),
#  ('landlord', 27),
#  ('Is', 27),
#  ('somewhat', 27),
#  ('certainly', 27),
#  ('m', 27),
#  ('seeing', 27),
#  ('eyeing', 27),
#  ('hope', 27),
#  ('Nevertheless', 27),
#  ('looks', 27),
#  ('overboard', 27),
#  ('sideways', 27),
#  ('command', 27),
#  ('dropped', 27),
#  ('wholly', 27),
#  ('born', 27),
#  ('ahead', 27),
#  ('alongside', 27),
#  ('Fedallah', 27),
#  ('play', 26),
#  ('received', 26),
#  ('enormous', 26),
#  ('island', 26),
#  ('whale-ship', 26),
#  ('degree', 26),
#  ('yourself', 26),
#  ('considerable', 26),
#  ('circumstances', 26),
#  ('started', 26),
#  ('followed', 26),
#  ('flying', 26),
#  ('wooden', 26),
#  ('ears', 26),
#  ('fancy', 26),
#  ('Upon', 26),
#  ('getting', 26),
#  ('yes', 26),
#  ('otherwise', 26),
#  ('giving', 26),
#  ('circumstance', 26),
#  ('read', 26),
#  ('From', 26),
#  ('bodily', 26),
#  ('suspended', 26),
#  ('pointed', 26),
#  ('whale-boat', 26),
#  ('blow', 26),
#  ('blubber', 26),
#  ('whiteness', 26),
#  ('yards', 25),
#  ('learned', 25),
#  ('Of', 25),
#  ('masts', 25),
#  ('carry', 25),
#  ('thrown', 25),
#  ('front', 25),
#  ('year', 25),
#  ('bit', 25),
#  ('silent', 25),
#  ('seated', 25),
#  ('chief', 25),
#  ('royal', 25),
#  ('believe', 25),
#  ('stop', 25),
#  ('thick', 25),
#  ('hump', 25),
#  ('cases', 25),
#  ('number', 25),
#  ('added', 25),
#  ('supper', 25),
#  ('chest', 25),
#  ('interval', 25),
#  ('duty', 25),
#  ('thinking', 25),
#  ('similar', 25),
#  ('skull', 25),
#  ('takes', 25),
#  ('complete', 25),
#  ('Thus', 25),
#  ('woe', 25),
#  ('bearing', 25),
#  ('twenty', 25),
#  ('steady', 25),
#  ('keel', 25),
#  ('coat', 24),
#  ('warm', 24),
#  ('grow', 24),
#  ('king', 24),
#  ('dart', 24),
#  ('thirty', 24),
#  ('floating', 24),
#  ('kill', 24),
#  ('seldom', 24),
#  ('love', 24),
#  ('finally', 24),
#  ('bright', 24),
#  ('blows', 24),
#  ('Dutch', 24),
#  ('different', 24),
#  ('regular', 24),
#  ('pursuit', 24),
#  ('storm', 24),
#  ('watery', 24),
#  ('drop', 24),
#  ('orders', 24),
#  ('exactly', 24),
#  ('perils', 24),
#  ('following', 24),
#  ('became', 24),
#  ('afterwards', 24),
#  ('swift', 24),
#  ('First', 24),
#  ('ran', 24),
#  ('wife', 24),
#  ('aside', 24),
#  ('escape', 24),
#  ('friend', 24),
#  ('hinted', 24),
#  ('hunters', 24),
#  ('spread', 24),
#  ('thyself', 24),
#  ('Stand', 24),
#  ('remains', 24),
#  ('St', 24),
#  ('oar', 24),
#  ('Lakeman', 24),
#  ('country', 23),
#  ('six', 23),
#  ('D', 23),
#  ('Like', 23),
#  ('regarded', 23),
#  ('vessels', 23),
#  ('honor', 23),
#  ('answer', 23),
#  ('port', 23),
#  ('beyond', 23),
#  ('nevertheless', 23),
#  ('gods', 23),
#  ('fiery', 23),
#  ('midnight', 23),
#  ('spring', 23),
#  ('wall', 23),
#  ('lances', 23),
#  ('flew', 23),
#  ('higher', 23),
#  ('somewhere', 23),
#  ('hot', 23),
#  ('passing', 23),
#  ('hidden', 23),
#  ('during', 23),
#  ('cutting', 23),
#  ('commanded', 23),
#  ('flesh', 23),
#  ('sweet', 23),
#  ('instead', 23),
#  ('hint', 23),
#  ('beat', 23),
#  ('rose', 23),
#  ('chapter', 23),
#  ('hence', 23),
#  ('lad', 23),
#  ('speaking', 23),
#  ('circle', 23),
#  ('strength', 23),
#  ('remain', 23),
#  ('secret', 23),
#  ('hunt', 23),
#  ('level', 23),
#  ('battle', 22),
#  ('forty', 22),
#  ('answered', 22),
#  ('My', 22),
#  ('stove', 22),
#  ('lives', 22),
#  ('rear', 22),
#  ('drawn', 22),
#  ('didn', 22),
#  ('wonderful', 22),
#  ('centre', 22),
#  ('filled', 22),
#  ('shipmates', 22),
#  ('hole', 22),
#  ('cause', 22),
#  ('game', 22),
#  ('real', 22),
#  ('owing', 22),
#  ('alive', 22),
#  ('drew', 22),
#  ('burst', 22),
#  ('deadly', 22),
#  ('descried', 22),
#  ('souls', 22),
#  ('Nantucketer', 22),
#  ('windward', 22),
#  ('shark', 22),
#  ('dashed', 22),
#  ('gazing', 22),
#  ('fin', 22),
#  ('pulling', 22),
#  ('Radney', 22),
#  ('shore', 21),
#  ('magnitude', 21),
#  ('striking', 21),
#  ('These', 21),
#  ('bound', 21),
#  ('decks', 21),
#  ('formed', 21),
#  ('original', 21),
#  ('Ha', 21),
#  ('sitting', 21),
#  ('negro', 21),
#  ('tall', 21),
#  ('spot', 21),
#  ('worse', 21),
#  ('talk', 21),
#  ('repeated', 21),
#  ('hair', 21),
#  ('minutes', 21),
#  ('spare', 21),
#  ('break', 21),
#  ('terrible', 21),
#  ('quickly', 21),
#  ...]

# %% [markdown]
# You'll notice that the most common words include a large number of words like "the" and "of". These can be considered "stop words", and in certain applications are less interesting and can be removed.
#
# NLTK includes lists of stop words.

# %%
stop_words = set(stopwords.words('english'))

stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %% [markdown]
# Let's make two modifications to our counter above. First, we'll covert all text to lowercase and the we'll remove stop words.

# %%
moby_counter = Counter([x.lower() for x in regexp_tokenize(moby, r'[-\'\w]+') if x.lower() not in stop_words])

# %%
len(moby_counter)
# Out:
# 18550

# %%
moby_counter.most_common()
# Out:
# [('whale', 1081),
#  ('one', 912),
#  ('like', 581),
#  ('upon', 565),
#  ('ahab', 506),
#  ('man', 499),
#  ('ye', 471),
#  ('ship', 470),
#  ('old', 443),
#  ('would', 430),
#  ('sea', 384),
#  ('though', 384),
#  ('yet', 344),
#  ('time', 326),
#  ('captain', 324),
#  ('long', 316),
#  ('still', 312),
#  ('said', 305),
#  ('great', 304),
#  ('boat', 287),
#  ('two', 286),
#  ('must', 283),
#  ('seemed', 283),
#  ('head', 277),
#  ('last', 276),
#  ('see', 272),
#  ('thou', 271),
#  ('whales', 267),
#  ('way', 266),
#  ('stubb', 255),
#  ('queequeg', 252),
#  ('little', 249),
#  ('white', 248),
#  ('round', 245),
#  ('say', 244),
#  ('three', 239),
#  ('may', 238),
#  ('men', 237),
#  ('sperm', 237),
#  ('first', 235),
#  ('every', 232),
#  ('us', 228),
#  ('much', 223),
#  ('well', 222),
#  ('could', 216),
#  ('never', 206),
#  ('hand', 204),
#  ('good', 198),
#  ('starbuck', 198),
#  ('almost', 195),
#  ('ever', 194),
#  ('go', 192),
#  ('even', 189),
#  ('side', 189),
#  ('thing', 188),
#  ('look', 185),
#  ('might', 183),
#  ('away', 180),
#  ('come', 179),
#  ('made', 177),
#  ('chapter', 173),
#  ('pequod', 172),
#  ('sir', 171),
#  ('world', 170),
#  ('water', 170),
#  ('among', 167),
#  ('many', 166),
#  ('seen', 164),
#  ('deck', 163),
#  ('day', 162),
#  ('far', 159),
#  ('let', 158),
#  ('eyes', 156),
#  ('without', 156),
#  ('oh', 156),
#  ('cried', 156),
#  ('aye', 154),
#  ('sort', 152),
#  ('know', 152),
#  ('back', 150),
#  ('thought', 149),
#  ('part', 148),
#  ('god', 145),
#  ('life', 145),
#  ('boats', 144),
#  ('right', 141),
#  ('air', 140),
#  ('crew', 140),
#  ('take', 137),
#  ('whole', 137),
#  ('night', 133),
#  ('things', 132),
#  ('thus', 132),
#  ('thee', 131),
#  ('came', 130),
#  ('soon', 130),
#  ('tell', 130),
#  ('hands', 128),
#  ('feet', 126),
#  ('small', 124),
#  ('till', 123),
#  ('think', 122),
#  ('line', 122),
#  ('something', 122),
#  ('nothing', 115),
#  ('saw', 115),
#  ('found', 115),
#  ('another', 115),
#  ('towards', 114),
#  ('called', 113),
#  ('full', 113),
#  ('whaling', 113),
#  ('poor', 112),
#  ('make', 112),
#  ('times', 112),
#  ('thy', 112),
#  ('place', 111),
#  ('body', 110),
#  ('heard', 110),
#  ('along', 110),
#  ('flask', 108),
#  ('fish', 107),
#  ('moment', 105),
#  ('sight', 104),
#  ('voyage', 101),
#  ('stand', 101),
#  ('high', 101),
#  ('strange', 97),
#  ('went', 97),
#  ('end', 96),
#  ('however', 95),
#  ('leviathan', 95),
#  ('shall', 95),
#  ('get', 95),
#  ('hold', 95),
#  ('face', 95),
#  ('years', 94),
#  ('nantucket', 92),
#  ('sun', 92),
#  ('also', 91),
#  ('whether', 91),
#  ('dead', 91),
#  ('half', 90),
#  ('stood', 90),
#  ('heart', 89),
#  ('certain', 89),
#  ('perhaps', 89),
#  ('indeed', 89),
#  ('leg', 88),
#  ('true', 87),
#  ('whose', 87),
#  ('sometimes', 87),
#  ('seas', 87),
#  ('seems', 87),
#  ('give', 86),
#  ('matter', 86),
#  ('black', 86),
#  ('arm', 85),
#  ('new', 85),
#  ('seem', 85),
#  ('going', 85),
#  ('jonah', 84),
#  ('sail', 84),
#  ('eye', 82),
#  ('soul', 82),
#  ('wild', 82),
#  ('standing', 82),
#  ('moby', 82),
#  ('dick', 82),
#  ('days', 81),
#  ('mind', 81),
#  ('known', 80),
#  ('always', 80),
#  ('hard', 80),
#  ('within', 79),
#  ('harpooneer', 79),
#  ('young', 79),
#  ('ere', 79),
#  ('present', 79),
#  ('length', 78),
#  ('oil', 78),
#  ('large', 78),
#  ('death', 78),
#  ('sailor', 78),
#  ('ships', 77),
#  ('tail', 77),
#  ('instant', 77),
#  ('bildad', 77),
#  ('word', 76),
#  ('least', 76),
#  ('beneath', 76),
#  ('enough', 76),
#  ('iron', 76),
#  ('land', 75),
#  ('set', 75),
#  ('yes', 75),
#  ('light', 75),
#  ('mate', 74),
#  ('morning', 74),
#  ('done', 74),
#  ('cabin', 74),
#  ('pip', 74),
#  ('vast', 73),
#  ('living', 73),
#  ('put', 73),
#  ('peleg', 73),
#  ('lay', 72),
#  ('rather', 72),
#  ('harpoon', 72),
#  ('bed', 72),
#  ('often', 72),
#  ('ocean', 71),
#  ('whalemen', 71),
#  ('case', 70),
#  ('near', 70),
#  ('wind', 69),
#  ('open', 69),
#  ('cannot', 69),
#  ('keep', 69),
#  ('name', 68),
#  ('four', 68),
#  ('point', 68),
#  ('therefore', 67),
#  ('general', 67),
#  ('business', 67),
#  ('deep', 66),
#  ('best', 66),
#  ('left', 66),
#  ('turned', 66),
#  ('waters', 66),
#  ('lord', 65),
#  ('since', 65),
#  ('fire', 65),
#  ('together', 64),
#  ('order', 64),
#  ('reason', 64),
#  ('looked', 64),
#  ('lower', 64),
#  ('hear', 63),
#  ('mr', 63),
#  ('better', 63),
#  ('board', 63),
#  ('aloft', 62),
#  ('turn', 61),
#  ('work', 60),
#  ('fishery', 60),
#  ('st', 60),
#  ('gone', 59),
#  ('mouth', 59),
#  ('second', 59),
#  ('chase', 59),
#  ('live', 59),
#  ('fine', 58),
#  ('book', 57),
#  ('feel', 57),
#  ('looking', 57),
#  ('find', 56),
#  ('indian', 56),
#  ('harpooneers', 56),
#  ('peculiar', 56),
#  ('home', 56),
#  ('dark', 56),
#  ('next', 56),
#  ('tashtego', 56),
#  ('goes', 55),
#  ('call', 55),
#  ('short', 55),
#  ('entire', 55),
#  ('run', 54),
#  ('blood', 54),
#  ('jaw', 54),
#  ('cook', 54),
#  ('bottom', 54),
#  ('curious', 54),
#  ('coming', 53),
#  ('vessel', 53),
#  ('close', 53),
#  ('less', 53),
#  ('taking', 53),
#  ('savage', 53),
#  ('began', 53),
#  ('comes', 53),
#  ('king', 52),
#  ('stern', 52),
#  ('slowly', 52),
#  ('turning', 52),
#  ('sailors', 52),
#  ('craft', 52),
#  ('forth', 52),
#  ('broad', 52),
#  ('mark', 52),
#  ('taken', 51),
#  ('grand', 51),
#  ('rest', 51),
#  ('ivory', 51),
#  ('devil', 50),
#  ('besides', 50),
#  ('behind', 50),
#  ('hundred', 50),
#  ('speak', 50),
#  ('sharks', 50),
#  ('green', 50),
#  ('thousand', 50),
#  ('forward', 50),
#  ('suddenly', 50),
#  ('nevertheless', 50),
#  ('_', 49),
#  ('cut', 49),
#  ('particular', 49),
#  ('story', 49),
#  ('took', 49),
#  ('view', 48),
#  ('waves', 48),
#  ('ten', 48),
#  ('voice', 48),
#  ('heaven', 48),
#  ('english', 48),
#  ('coffin', 48),
#  ('common', 48),
#  ('used', 48),
#  ('stranger', 48),
#  ('carpenter', 48),
#  ('bows', 48),
#  ('pull', 48),
#  ('lost', 47),
#  ('mighty', 47),
#  ('told', 47),
#  ('several', 47),
#  ('struck', 47),
#  ('watch', 47),
#  ('kept', 47),
#  ('earth', 46),
#  ('whatever', 46),
#  ('touching', 46),
#  ('teeth', 46),
#  ('form', 46),
#  ('people', 46),
#  ('fellow', 46),
#  ('whaleman', 46),
#  ('rope', 46),
#  ('sleep', 46),
#  ('else', 46),
#  ('says', 46),
#  ('broken', 46),
#  ('got', 46),
#  ('fast', 46),
#  ('spout', 46),
#  ('monster', 45),
#  ('bones', 45),
#  ('caught', 45),
#  ('sat', 45),
#  ('sure', 45),
#  ('straight', 45),
#  ('mine', 45),
#  ('fact', 45),
#  ('queer', 44),
#  ('somehow', 44),
#  ('noble', 44),
#  ('chance', 44),
#  ('wide', 44),
#  ('especially', 44),
#  ('room', 44),
#  ('heads', 44),
#  ('running', 44),
#  ('means', 44),
#  ('making', 43),
#  ('knew', 43),
#  ('nigh', 43),
#  ('blue', 43),
#  ('anything', 43),
#  ('rolled', 43),
#  ('mere', 42),
#  ('nature', 42),
#  ('hours', 42),
#  ('passed', 42),
#  ('door', 42),
#  ('seamen', 42),
#  ('em', 42),
#  ('sudden', 42),
#  ('creature', 42),
#  ('wondrous', 42),
#  ('surface', 42),
#  ('alone', 41),
#  ('clear', 41),
#  ('art', 41),
#  ('calm', 41),
#  ('lance', 41),
#  ('quite', 41),
#  ('parts', 41),
#  ('sharp', 41),
#  ('felt', 41),
#  ('course', 41),
#  ('sound', 41),
#  ('either', 40),
#  ('purpose', 40),
#  ('wake', 40),
#  ('mortal', 40),
#  ('boy', 40),
#  ('mean', 40),
#  ('quick', 40),
#  ('ready', 40),
#  ('saying', 40),
#  ('concerning', 40),
#  ('mates', 40),
#  ('ground', 40),
#  ('brow', 40),
#  ('steelkilt', 40),
#  ('others', 39),
#  ('plainly', 39),
#  ('distance', 39),
#  ('bow', 39),
#  ('object', 39),
#  ('mass', 39),
#  ('hour', 39),
#  ('makes', 39),
#  ('oars', 39),
#  ('leaving', 38),
#  ('brought', 38),
#  ('fixed', 38),
#  ('around', 38),
#  ('mast-head', 38),
#  ('single', 38),
#  ('various', 38),
#  ('sailed', 38),
#  ('plain', 38),
#  ('forehead', 38),
#  ('five', 38),
#  ('help', 38),
#  ('cry', 38),
#  ('darted', 38),
#  ('gave', 38),
#  ('hat', 38),
#  ('power', 38),
#  ('gentlemen', 38),
#  ('placed', 37),
#  ('coast', 37),
#  ('manner', 37),
#  ('bulwarks', 37),
#  ('bear', 37),
#  ('easy', 37),
#  ('famous', 37),
#  ('low', 37),
#  ('suppose', 37),
#  ('holding', 37),
#  ('human', 37),
#  ('bone', 37),
#  ('held', 37),
#  ('flukes', 37),
#  ('aspect', 37),
#  ('sails', 37),
#  ('daggoo', 37),
#  ('greenland', 36),
#  ('ago', 36),
#  ('mad', 36),
#  ('fell', 36),
#  ('legs', 36),
#  ('forecastle', 36),
#  ('cape', 36),
#  ('middle', 36),
#  ('ha', 36),
#  ('unknown', 36),
#  ('seeing', 36),
#  ('truth', 36),
#  ('top', 36),
#  ('use', 36),
#  ('given', 36),
#  ('natural', 36),
#  ('strong', 35),
#  ('killed', 35),
#  ('pipe', 35),
#  ('previous', 35),
#  ('sign', 35),
#  ('gold', 35),
#  ('helm', 35),
#  ('brain', 34),
#  ('ashore', 34),
#  ('account', 34),
#  ('passage', 34),
#  ('pacific', 34),
#  ('nearly', 34),
#  ('american', 34),
#  ('shot', 34),
#  ('boys', 34),
#  ('red', 34),
#  ('house', 34),
#  ('landlord', 34),
#  ('wonder', 34),
#  ('none', 34),
#  ('thoughts', 34),
#  ('heavy', 34),
#  ('arms', 34),
#  ('hope', 34),
#  ('turns', 34),
#  ('remained', 34),
#  ('skeleton', 34),
#  ('start', 34),
#  ('sailing', 34),
#  ('de', 34),
#  ('fifty', 33),
#  ('creatures', 33),
#  ('fear', 33),
#  ('rigging', 33),
#  ('idea', 33),
#  ('stop', 33),
#  ('want', 33),
#  ('company', 33),
#  ('hammock', 33),
#  ('skin', 33),
#  ('fair', 33),
#  ('completely', 33),
#  ('drawing', 33),
#  ('hardly', 33),
#  ('rolling', 32),
#  ('strike', 32),
#  ('bulk', 32),
#  ('doubt', 32),
#  ('miles', 32),
#  ('mast-heads', 32),
#  ('already', 32),
#  ('darkness', 32),
#  ('lines', 32),
#  ('table', 32),
#  ('third', 32),
#  ('show', 32),
#  ('proper', 32),
#  ('hence', 32),
#  ('aft', 32),
#  ('intervals', 32),
#  ('hull', 32),
#  ('generally', 31),
#  ('try', 31),
#  ('species', 31),
#  ('island', 31),
#  ('upper', 31),
#  ('chief', 31),
#  ('considering', 31),
#  ('harpoons', 31),
#  ('jet', 31),
#  ('visible', 31),
#  ('planks', 31),
#  ('weather', 31),
#  ('sky', 31),
#  ('substance', 31),
#  ('across', 31),
#  ('pass', 31),
#  ('woe', 31),
#  ('nose', 31),
#  ('except', 31),
#  ('instances', 31),
#  ('rising', 31),
#  ('late', 30),
#  ('swimming', 30),
#  ('huge', 30),
#  ('steel', 30),
#  ('fresh', 30),
#  ('possible', 30),
#  ('possibly', 30),
#  ('act', 30),
#  ('really', 30),
#  ('quarter-deck', 30),
#  ('cold', 30),
#  ('spring', 30),
#  ('supper', 30),
#  ('soft', 30),
#  ('wood', 30),
#  ('carried', 30),
#  ('cast', 30),
#  ('die', 30),
#  ('born', 30),
#  ('altogether', 29),
#  ('hast', 29),
#  ('jaws', 29),
#  ('pretty', 29),
#  ('entirely', 29),
#  ('steady', 29),
#  ('smoke', 29),
#  ('vain', 29),
#  ('unless', 29),
#  ('mast', 29),
#  ('astern', 29),
#  ('horn', 29),
#  ('nay', 29),
#  ('foot', 29),
#  ('words', 29),
#  ('tossed', 29),
#  ('final', 29),
#  ('stands', 29),
#  ('mariners', 29),
#  ('certainly', 29),
#  ('touch', 29),
#  ('question', 29),
#  ('sideways', 29),
#  ('suspended', 29),
#  ('strangely', 29),
#  ('hammer', 29),
#  ('leeward', 29),
#  ('hoisted', 29),
#  ('ancient', 28),
#  ('fishermen', 28),
#  ('free', 28),
#  ('whale-ship', 28),
#  ('gale', 28),
#  ('leaning', 28),
#  ('knows', 28),
#  ('mild', 28),
#  ('meanwhile', 28),
#  ('hung', 28),
#  ('shipmates', 28),
#  ('become', 28),
#  ('feeling', 28),
#  ('person', 28),
#  ('thinking', 28),
#  ('giving', 28),
#  ('glance', 28),
#  ('parsee', 28),
#  ('hearts', 27),
#  ('sides', 27),
#  ('lie', 27),
#  ('kind', 27),
#  ('tis', 27),
#  ('finally', 27),
#  ('precisely', 27),
#  ('believe', 27),
#  ('started', 27),
#  ('flying', 27),
#  ('wooden', 27),
#  ('scene', 27),
#  ('somewhat', 27),
#  ('eyeing', 27),
#  ('looks', 27),
#  ('overboard', 27),
#  ('read', 27),
#  ('father', 27),
#  ('command', 27),
#  ('dropped', 27),
#  ('wholly', 27),
#  ('ahead', 27),
#  ('alongside', 27),
#  ('whiteness', 27),
#  ('fedallah', 27),
#  ('play', 26),
#  ('received', 26),
#  ('floating', 26),
#  ('year', 26),
#  ('enormous', 26),
#  ('degree', 26),
#  ('silent', 26),
#  ('seated', 26),
#  ('considerable', 26),
#  ('circumstances', 26),
#  ('followed', 26),
#  ('ears', 26),
#  ('gods', 26),
#  ('midnight', 26),
#  ('fancy', 26),
#  ('getting', 26),
#  ('otherwise', 26),
#  ('circumstance', 26),
#  ('sweet', 26),
#  ('keel', 26),
#  ('bodily', 26),
#  ('pointed', 26),
#  ('according', 26),
#  ('whale-boat', 26),
#  ('blow', 26),
#  ('blubber', 26),
#  ('yards', 25),
#  ('dart', 25),
#  ('learned', 25),
#  ('thirty', 25),
#  ('masts', 25),
#  ('kill', 25),
#  ('seldom', 25),
#  ('carry', 25),
#  ('thrown', 25),
#  ('bright', 25),
#  ('front', 25),
#  ('forty', 25),
#  ('thunder', 25),
#  ('bit', 25),
#  ('dutch', 25),
#  ('watery', 25),
#  ('drop', 25),
#  ('royal', 25),
#  ('answer', 25),
#  ('thick', 25),
#  ('afterwards', 25),
#  ('talk', 25),
#  ('hump', 25),
#  ('cases', 25),
#  ('number', 25),
#  ('added', 25),
#  ('chest', 25),
#  ('interval', 25),
#  ('duty', 25),
#  ('similar', 25),
#  ('skull', 25),
#  ('takes', 25),
#  ('wife', 25),
#  ('cutting', 25),
#  ('aside', 25),
#  ('complete', 25),
#  ('friend', 25),
#  ('bearing', 25),
#  ('twenty', 25),
#  ('spread', 25),
#  ('shark', 25),
#  ('coat', 24),
#  ('warm', 24),
#  ('grow', 24),
#  ('battle', 24),
#  ('love', 24),
#  ('regarded', 24),
#  ('blows', 24),
#  ('different', 24),
#  ('regular', 24),
#  ('pursuit', 24),
#  ('storm', 24),
#  ('honor', 24),
#  ('orders', 24),
#  ('exactly', 24),
#  ('perils', 24),
#  ('following', 24),
#  ('port', 24),
#  ('became', 24),
#  ('beyond', 24),
#  ('fiery', 24),
#  ('wall', 24),
#  ('swift', 24),
#  ('ran', 24),
#  ('owing', 24),
#  ('commanded', 24),
#  ('instead', 24),
#  ('beat', 24),
#  ('rose', 24),
#  ('lad', 24),
#  ('escape', 24),
#  ('hinted', 24),
#  ('strength', 24),
#  ('hunters', 24),
#  ('thyself', 24),
#  ('remains', 24),
#  ('level', 24),
#  ('pulling', 24),
#  ('oar', 24),
#  ('lakeman', 24),
#  ('country', 23),
#  ('six', 23),
#  ('shore', 23),
#  ('globe', 23),
#  ('south', 23),
#  ('vessels', 23),
#  ('ah', 23),
#  ('drawn', 23),
#  ('lances', 23),
#  ('flew', 23),
#  ('higher', 23),
#  ('somewhere', 23),
#  ('hot', 23),
#  ('passing', 23),
#  ('real', 23),
#  ('hidden', 23),
#  ('meantime', 23),
#  ('pagan', 23),
#  ('instantly', 23),
#  ('alive', 23),
#  ('flesh', 23),
#  ('burst', 23),
#  ('hint', 23),
#  ('speaking', 23),
#  ('circle', 23),
#  ('consider', 23),
#  ('remain', 23),
#  ('secret', 23),
#  ('hunt', 23),
#  ('state', 22),
#  ('magnitude', 22),
#  ('french', 22),
#  ('answered', 22),
#  ('stove', 22),
#  ('striking', 22),
#  ('eight', 22),
#  ('lives', 22),
#  ('rear', 22),
#  ('negro', 22),
#  ('tall', 22),
#  ('wonderful', 22),
#  ('centre', 22),
#  ('filled', 22),
#  ('avast', 22),
#  ('hole', 22),
#  ('cause', 22),
#  ('likewise', 22),
#  ('terrible', 22),
#  ('game', 22),
#  ('drew', 22),
#  ('deadly', 22),
#  ('descried', 22),
#  ('captains', 22),
#  ('souls', 22),
#  ('nantucketer', 22),
#  ('windward', 22),
#  ('sink', 22),
#  ('dashed', 22),
#  ('gazing', 22),
#  ('advance', 22),
#  ('fin', 22),
#  ('radney', 22),
#  ('swim', 21),
#  ('sing', 21),
#  ('history', 21),
#  ('bound', 21),
#  ('decks', 21),
#  ('formed', 21),
#  ('original', 21),
#  ('sitting', 21),
#  ('spot', 21),
#  ('worse', 21),
#  ('repeated', 21),
#  ('truly', 21),
#  ('hair', 21),
#  ('minutes', 21),
#  ('spare', 21),
#  ('break', 21),
#  ('aboard', 21),
#  ('pilot', 21),
#  ('quickly', 21),
#  ('lofty', 21),
#  ('age', 21),
#  ('step', 21),
#  ('prow', 21),
#  ('terrors', 21),
#  ('base', 21),
#  ('hailed', 21),
#  ('invested', 21),
#  ('evinced', 21),
#  ('attached', 21),
#  ('beheld', 21),
#  ('gunwale', 21),
#  ('blacksmith', 21),
#  ('gabriel', 20),
#  ('former', 20),
#  ('holy', 20),
#  ('master', 20),
#  ('ribs', 20),
#  ('swam', 20),
#  ('everything', 20),
#  ('directly', 20),
#  ('ishmael', 20),
#  ('virtue', 20),
#  ('distant', 20),
#  ('winds', 20),
#  ('lies', 20),
#  ('separate', 20),
#  ('needs', 20),
#  ('thinks', 20),
#  ('jolly', 20),
#  ('swung', 20),
#  ('inches', 20),
#  ('dim', 20),
#  ('england', 20),
#  ('drive', 20),
#  ('gigantic', 20),
#  ('subject', 20),
#  ('fain', 20),
#  ('raised', 20),
#  ('sleeping', 20),
#  ('follow', 20),
#  ('lamp', 20),
#  ('outer', 20),
#  ('past', 20),
#  ('law', 20),
#  ('profound', 20),
#  ('slightest', 20),
#  ('died', 20),
#  ('son', 20),
#  ('laid', 20),
#  ('billows', 20),
#  ('hanging', 20),
#  ('moreover', 20),
#  ('loose', 20),
#  ('dost', 20),
#  ('squall', 20),
#  ('log', 20),
#  ('windlass', 20),
#  ('000', 20),
#  ('dignity', 20),
#  ('golden', 20),
#  ('cruising', 20),
#  ('lowered', 20),
#  ('pole', 20),
#  ('terror', 20),
#  ('dat', 20),
#  ('doubloon', 20),
#  ('pale', 19),
#  ('empty', 19),
#  ('bring', 19),
#  ('important', 19),
#  ('largest', 19),
#  ('ordinary', 19),
#  ('spermaceti', 19),
#  ('pointing', 19),
#  ('lightning', 19),
#  ('meet', 19),
#  ('vicinity', 19),
#  ('tree', 19),
#  ('leaves', 19),
#  ('hollow', 19),
#  ('picture', 19),
#  ('deeper', 19),
#  ('presented', 19),
#  ('presently', 19),
#  ('cannibal', 19),
#  ('seat', 19),
#  ('sake', 19),
#  ('met', 19),
#  ('ones', 19),
#  ('floor', 19),
#  ('anchor', 19),
#  ('jacket', 19),
#  ('beginning', 19),
#  ('yellow', 19),
#  ('concluded', 19),
#  ('places', 19),
#  ('smoking', 19),
#  ('precise', 19),
#  ('awful', 19),
#  ('ways', 19),
#  ('hunted', 19),
#  ('stuff', 19),
#  ('solitary', 19),
#  ('silence', 19),
#  ('eternal', 19),
#  ('upwards', 19),
#  ('swiftly', 19),
#  ('reached', 19),
#  ('chiefly', 19),
#  ('merely', 19),
#  ('whaler', 19),
#  ('gentleman', 19),
#  ('casks', 19),
#  ('breeze', 19),
#  ('eh', 19),
#  ('officers', 19),
#  ('sorts', 19),
#  ('rapidly', 19),
#  ('whalers', 19),
#  ('whereas', 18),
#  ('modern', 18),
#  ('breath', 18),
#  ('forced', 18),
#  ('atlantic', 18),
#  ('observed', 18),
#  ('christian', 18),
#  ('engaged', 18),
#  ('lee', 18),
#  ('interest', 18),
#  ('quietly', 18),
#  ('content', 18),
#  ('yonder', 18),
#  ('east', 18),
#  ('beach', 18),
#  ('glory', 18),
#  ('instance', 18),
#  ('difference', 18),
#  ('nameless', 18),
#  ('floated', 18),
#  ('bedford', 18),
#  ('ice', 18),
#  ('careful', 18),
#  ('opposite', 18),
#  ('crossing', 18),
#  ('sought', 18),
#  ('telling', 18),
#  ('rate', 18),
#  ('evening', 18),
#  ('height', 18),
#  ('kings', 18),
#  ('inside', 18),
#  ('dropping', 18),
#  ('rise', 18),
#  ('guess', 18),
#  ('thereby', 18),
#  ('prodigious', 18),
#  ('fight', 18),
#  ('lying', 18),
#  ('leave', 18),
#  ('lo', 18),
#  ('spite', 18),
#  ('brave', 18),
#  ('thine', 18),
#  ('fall', 18),
#  ('delight', 18),
#  ('gives', 18),
#  ('regularly', 18),
#  ('wise', 18),
#  ('owners', 18),
#  ('drink', 18),
#  ('intense', 18),
#  ('advancing', 18),
#  ...]

# %% [markdown]
# We might also want to do further preprocessing of our text. Let's try stemming and lemmatization. First, let's look at stemming. We'll try out the PorterStemmer from NLTK.

# %%
porter = PorterStemmer()

# %% [markdown]
# To use it, you just need to call the `.stem` method and pass in the token to be stemmed.

# %%
porter.stem('whales')
# Out:
# 'whale'

# %%
porter.stem('numerical')
# Out:
# 'numer'

# %%
moby_counter = Counter([porter.stem(x.lower()) for x in regexp_tokenize(moby, r'[-\'\w]+') if x.lower() not in stop_words])

# %%
len(moby_counter)
# Out:
# 12349

# %%
moby_counter.most_common()
# Out:
# [('whale', 1462),
#  ('one', 932),
#  ('like', 595),
#  ('upon', 565),
#  ('ship', 565),
#  ('ye', 546),
#  ('man', 512),
#  ('ahab', 507),
#  ('sea', 471),
#  ('seem', 463),
#  ('old', 443),
#  ('time', 441),
#  ('boat', 431),
#  ('would', 430),
#  ('though', 384),
#  ('hand', 349),
#  ('captain', 346),
#  ('yet', 344),
#  ('head', 340),
#  ('look', 333),
#  ('say', 330),
#  ('long', 321),
#  ('thing', 320),
#  ('still', 315),
#  ('see', 312),
#  ('great', 306),
#  ('said', 305),
#  ('two', 289),
#  ('come', 286),
#  ('way', 285),
#  ('must', 283),
#  ('last', 280),
#  ('white', 278),
#  ('go', 277),
#  ('eye', 271),
#  ('thou', 271),
#  ('round', 258),
#  ('stubb', 257),
#  ('queequeg', 252),
#  ('littl', 249),
#  ('harpoon', 248),
#  ('day', 243),
#  ('three', 242),
#  ('may', 238),
#  ('men', 237),
#  ('sperm', 237),
#  ('water', 236),
#  ('first', 235),
#  ('everi', 232),
#  ('us', 228),
#  ('well', 223),
#  ('much', 223),
#  ('side', 218),
#  ('could', 216),
#  ('take', 215),
#  ('cri', 214),
#  ('turn', 213),
#  ('stand', 212),
#  ('even', 207),
#  ('never', 206),
#  ('good', 204),
#  ('part', 199),
#  ('starbuck', 198),
#  ('know', 196),
#  ('almost', 195),
#  ('ever', 194),
#  ('make', 194),
#  ('sail', 194),
#  ('call', 192),
#  ('thought', 185),
#  ('deck', 184),
#  ('might', 183),
#  ('live', 181),
#  ('chapter', 181),
#  ('away', 180),
#  ('world', 177),
#  ('made', 177),
#  ('place', 174),
#  ('think', 172),
#  ('sir', 172),
#  ('pequod', 172),
#  ('god', 171),
#  ('sort', 171),
#  ('back', 170),
#  ('among', 167),
#  ('mani', 166),
#  ('seen', 164),
#  ('let', 162),
#  ('far', 159),
#  ('crew', 157),
#  ('without', 156),
#  ('line', 156),
#  ('oh', 156),
#  ('tell', 156),
#  ('aye', 154),
#  ('right', 149),
#  ('life', 145),
#  ('night', 144),
#  ('air', 140),
#  ('hold', 139),
#  ('whole', 137),
#  ('give', 132),
#  ('thu', 132),
#  ('thee', 131),
#  ('came', 130),
#  ('soon', 130),
#  ('sailor', 130),
#  ('arm', 129),
#  ('strang', 129),
#  ('present', 129),
#  ('voyag', 128),
#  ('point', 127),
#  ('feet', 126),
#  ('small', 125),
#  ('get', 125),
#  ('nantucket', 124),
#  ('leg', 124),
#  ('till', 123),
#  ('someth', 122),
#  ('leviathan', 121),
#  ('moment', 121),
#  ('year', 120),
#  ('bodi', 119),
#  ('found', 119),
#  ('sight', 119),
#  ('saw', 118),
#  ('heart', 117),
#  ('face', 117),
#  ('gener', 116),
#  ('end', 116),
#  ('noth', 115),
#  ('anoth', 115),
#  ('fish', 114),
#  ('toward', 114),
#  ('mate', 114),
#  ('full', 113),
#  ('poor', 112),
#  ('thi', 112),
#  ('heard', 110),
#  ('along', 110),
#  ('flask', 109),
#  ('use', 108),
#  ('roll', 107),
#  ('feel', 107),
#  ('run', 106),
#  ('lower', 106),
#  ('word', 105),
#  ('mean', 105),
#  ('bow', 104),
#  ('soul', 104),
#  ('high', 103),
#  ('light', 103),
#  ('matter', 99),
#  ('black', 99),
#  ('pass', 98),
#  ('name', 97),
#  ('case', 97),
#  ('order', 97),
#  ('went', 97),
#  ('mind', 96),
#  ('howev', 95),
#  ('shall', 95),
#  ('land', 95),
#  ('work', 95),
#  ('natur', 95),
#  ('wind', 95),
#  ('sun', 95),
#  ('open', 94),
#  ('iron', 94),
#  ('form', 93),
#  ('set', 92),
#  ('put', 92),
#  ('remain', 92),
#  ('also', 91),
#  ('whether', 91),
#  ('dead', 91),
#  ('touch', 90),
#  ('half', 90),
#  ('reason', 90),
#  ('stood', 90),
#  ('keep', 90),
#  ('certain', 89),
#  ('perhap', 89),
#  ('inde', 89),
#  ('dark', 88),
#  ('mark', 88),
#  ('true', 87),
#  ('whose', 87),
#  ('sometim', 87),
#  ('ocean', 87),
#  ('larg', 87),
#  ('spout', 86),
#  ('wild', 86),
#  ('pull', 86),
#  ('tail', 85),
#  ('carri', 85),
#  ('new', 85),
#  ('jonah', 84),
#  ('entir', 84),
#  ('jaw', 83),
#  ('lay', 83),
#  ('bone', 82),
#  ('hear', 82),
#  ('mobi', 82),
#  ('dick', 82),
#  ('length', 81),
#  ('dart', 81),
#  ('close', 81),
#  ('hour', 81),
#  ('chase', 81),
#  ('hard', 81),
#  ('wonder', 81),
#  ('known', 80),
#  ('oil', 80),
#  ('death', 80),
#  ('alway', 80),
#  ('command', 80),
#  ('within', 79),
#  ('young', 79),
#  ('ere', 79),
#  ('near', 78),
#  ('sound', 78),
#  ('cut', 77),
#  ('speak', 77),
#  ('instant', 77),
#  ('watch', 77),
#  ('bed', 77),
#  ('morn', 77),
#  ('bildad', 77),
#  ('leav', 76),
#  ('least', 76),
#  ('vessel', 76),
#  ('beneath', 76),
#  ('shark', 76),
#  ('mr', 76),
#  ('drop', 76),
#  ('enough', 76),
#  ('start', 76),
#  ('often', 76),
#  ('creatur', 75),
#  ('bear', 75),
#  ('busi', 75),
#  ('cabin', 75),
#  ('mouth', 74),
#  ('sleep', 74),
#  ('peculiar', 74),
#  ('boy', 74),
#  ('follow', 74),
#  ('done', 74),
#  ('pip', 74),
#  ('find', 73),
#  ('vast', 73),
#  ('peleg', 73),
#  ('book', 72),
#  ('board', 72),
#  ('rather', 72),
#  ('fire', 71),
#  ('mast-head', 71),
#  ('whalemen', 71),
#  ('deep', 70),
#  ('wave', 70),
#  ('king', 70),
#  ('die', 70),
#  ('lord', 69),
#  ('chanc', 69),
#  ('cannot', 69),
#  ('four', 68),
#  ('consid', 68),
#  ('devil', 67),
#  ('therefor', 67),
#  ('rest', 67),
#  ('complet', 67),
#  ('best', 66),
#  ('kill', 66),
#  ('thousand', 66),
#  ('possibl', 66),
#  ('left', 66),
#  ('heaven', 65),
#  ('sinc', 65),
#  ('lie', 65),
#  ('togeth', 64),
#  ('float', 64),
#  ('tri', 64),
#  ('better', 64),
#  ('lanc', 64),
#  ('savag', 64),
#  ('cook', 64),
#  ('fisheri', 64),
#  ('continu', 63),
#  ('oar', 63),
#  ('aloft', 62),
#  ('want', 62),
#  ('concern', 62),
#  ('mere', 61),
#  ('quit', 61),
#  ('hint', 61),
#  ('indian', 60),
#  ('second', 60),
#  ('show', 60),
#  ('st', 60),
#  ('gone', 59),
#  ('strike', 59),
#  ('swim', 59),
#  ('fear', 59),
#  ('stori', 59),
#  ('hundr', 58),
#  ('suppos', 58),
#  ('wake', 58),
#  ('particular', 58),
#  ('help', 58),
#  ('fine', 58),
#  ('sign', 58),
#  ('rise', 58),
#  ('stern', 57),
#  ('fellow', 57),
#  ('home', 57),
#  ('interv', 57),
#  ('advanc', 57),
#  ('view', 56),
#  ('besid', 56),
#  ('voic', 56),
#  ('final', 56),
#  ('blow', 56),
#  ('short', 56),
#  ('coffin', 56),
#  ('next', 56),
#  ('tashtego', 56),
#  ('glanc', 55),
#  ('goe', 55),
#  ('sever', 55),
#  ('blood', 55),
#  ('account', 55),
#  ('object', 55),
#  ('forward', 55),
#  ('rope', 55),
#  ('bottom', 55),
#  ('stranger', 55),
#  ('mortal', 54),
#  ('mast', 54),
#  ('lean', 54),
#  ('peril', 54),
#  ('curiou', 54),
#  ('clear', 53),
#  ('monster', 53),
#  ('ground', 53),
#  ('island', 53),
#  ('green', 53),
#  ('less', 53),
#  ('mad', 53),
#  ('smoke', 53),
#  ('began', 53),
#  ('sure', 52),
#  ('slowli', 52),
#  ('circumst', 52),
#  ('craft', 52),
#  ('forth', 52),
#  ('broad', 52),
#  ('fact', 52),
#  ('carpent', 52),
#  ('hunt', 52),
#  ('taken', 51),
#  ('ten', 51),
#  ('grand', 51),
#  ('ivori', 51),
#  ('receiv', 50),
#  ('draw', 50),
#  ('behind', 50),
#  ('marin', 50),
#  ('answer', 50),
#  ('wide', 50),
#  ('suddenli', 50),
#  ('common', 50),
#  ('toss', 50),
#  ('nevertheless', 50),
#  ('gaze', 50),
#  ('hoist', 50),
#  ('fast', 50),
#  ('_', 49),
#  ('consider', 49),
#  ('purpos', 49),
#  ('observ', 49),
#  ('rush', 49),
#  ('power', 49),
#  ('precis', 49),
#  ('seat', 49),
#  ('instanc', 49),
#  ('stop', 49),
#  ('took', 49),
#  ('peopl', 48),
#  ('english', 48),
#  ('door', 48),
#  ('plank', 48),
#  ('love', 47),
#  ('lost', 47),
#  ('mighti', 47),
#  ('told', 47),
#  ('struck', 47),
#  ('differ', 47),
#  ('mass', 47),
#  ('kept', 47),
#  ('cours', 47),
#  ('earth', 46),
#  ('whatev', 46),
#  ('teeth', 46),
#  ('fli', 46),
#  ('calm', 46),
#  ('person', 46),
#  ('whaleman', 46),
#  ('rig', 46),
#  ('reach', 46),
#  ('care', 46),
#  ('els', 46),
#  ('hous', 46),
#  ('broken', 46),
#  ('room', 46),
#  ('got', 46),
#  ('art', 45),
#  ('doubt', 45),
#  ('caught', 45),
#  ('coast', 45),
#  ('rock', 45),
#  ('sat', 45),
#  ('straight', 45),
#  ('cross', 45),
#  ('mine', 45),
#  ('human', 45),
#  ('readi', 45),
#  ('hail', 45),
#  ('brain', 44),
#  ('queer', 44),
#  ('somehow', 44),
#  ('nobl', 44),
#  ('breath', 44),
#  ('pipe', 44),
#  ('respect', 44),
#  ('especi', 44),
#  ('offic', 44),
#  ('hope', 44),
#  ('direct', 44),
#  ('hammer', 44),
#  ('secur', 43),
#  ('knew', 43),
#  ('nigh', 43),
#  ('blue', 43),
#  ('anyth', 43),
#  ('origin', 43),
#  ('jet', 43),
#  ('fill', 43),
#  ('becom', 43),
#  ('sudden', 43),
#  ('drag', 43),
#  ('question', 43),
#  ('friend', 42),
#  ('move', 42),
#  ('regard', 42),
#  ('leap', 42),
#  ('step', 42),
#  ('hat', 42),
#  ('need', 42),
#  ('begin', 42),
#  ('seamen', 42),
#  ('em', 42),
#  ('heav', 42),
#  ('brow', 42),
#  ('aspect', 42),
#  ('circl', 42),
#  ('wondrou', 42),
#  ('seiz', 42),
#  ('encount', 42),
#  ('surfac', 42),
#  ('alon', 41),
#  ('fanci', 41),
#  ('sit', 41),
#  ('fix', 41),
#  ('distanc', 41),
#  ('meet', 41),
#  ('silent', 41),
#  ('sharp', 41),
#  ('plain', 41),
#  ('age', 41),
#  ('break', 41),
#  ('fluke', 41),
#  ('felt', 41),
#  ('wood', 41),
#  ('sky', 41),
#  ('terror', 41),
#  ('murder', 41),
#  ('fit', 41),
#  ('dash', 41),
#  ('appear', 40),
#  ('rais', 40),
#  ('state', 40),
#  ('either', 40),
#  ('belong', 40),
#  ('american', 40),
#  ('happen', 40),
#  ('quick', 40),
#  ('forehead', 40),
#  ('shipmat', 40),
#  ('escap', 40),
#  ('steelkilt', 40),
#  ('other', 39),
#  ('play', 39),
#  ('learn', 39),
#  ('plainli', 39),
#  ('lad', 39),
#  ('idea', 39),
#  ('compani', 39),
#  ('caus', 39),
#  ('truth', 39),
#  ('top', 39),
#  ('cast', 39),
#  ('born', 39),
#  ('keel', 39),
#  ('skeleton', 39),
#  ('brought', 38),
#  ('return', 38),
#  ('rib', 38),
#  ('around', 38),
#  ('hunter', 38),
#  ('mile', 38),
#  ('manner', 38),
#  ('singl', 38),
#  ('variou', 38),
#  ('conclud', 38),
#  ('red', 38),
#  ('five', 38),
#  ('minut', 38),
#  ('gave', 38),
#  ('flame', 38),
#  ('gain', 38),
#  ('lift', 38),
#  ('except', 38),
#  ('whaler', 38),
#  ('gentlemen', 38),
#  ('beat', 37),
#  ('enter', 37),
#  ('greenland', 37),
#  ('suspend', 37),
#  ('horn', 37),
#  ('whale-ship', 37),
#  ('fell', 37),
#  ('bulwark', 37),
#  ('forecastl', 37),
#  ('easi', 37),
#  ('cape', 37),
#  ('famou', 37),
#  ('middl', 37),
#  ('low', 37),
#  ('ear', 37),
#  ('talk', 37),
#  ('scene', 37),
#  ('wall', 37),
#  ('held', 37),
#  ('read', 37),
#  ('level', 37),
#  ('hull', 37),
#  ('daggoo', 37),
#  ('pacif', 36),
#  ('ago', 36),
#  ('separ', 36),
#  ('honor', 36),
#  ('act', 36),
#  ('believ', 36),
#  ('spring', 36),
#  ('ha', 36),
#  ('unknown', 36),
#  ('third', 36),
#  ('given', 36),
#  ('sink', 36),
#  ('strong', 35),
#  ('tow', 35),
#  ('mention', 35),
#  ('passag', 35),
#  ('sing', 35),
#  ('paus', 35),
#  ('previou', 35),
#  ('pictur', 35),
#  ('invest', 35),
#  ('inch', 35),
#  ('tabl', 35),
#  ('heavi', 35),
#  ('burst', 35),
#  ('gold', 35),
#  ('etern', 35),
#  ('helm', 35),
#  ('nose', 35),
#  ('grow', 34),
#  ('fifti', 34),
#  ('ashor', 34),
#  ('nearli', 34),
#  ('thunder', 34),
#  ('shot', 34),
#  ('landlord', 34),
#  ('hammock', 34),
#  ('skin', 34),
#  ('none', 34),
#  ('de', 34),
#  ('bulk', 33),
#  ('forc', 33),
#  ('kind', 33),
#  ('compar', 33),
#  ('cruis', 33),
#  ('bit', 33),
#  ('storm', 33),
#  ('mild', 33),
#  ('visibl', 33),
#  ('weather', 33),
#  ('fair', 33),
#  ('pitch', 33),
#  ('hardli', 33),
#  ('substanc', 33),
#  ('intent', 33),
#  ('fin', 33),
#  ('blind', 33),
#  ('motion', 32),
#  ('huge', 32),
#  ('bring', 32),
#  ('captur', 32),
#  ('drive', 32),
#  ('fall', 32),
#  ('chief', 32),
#  ('alreadi', 32),
#  ('thick', 32),
#  ('prove', 32),
#  ('row', 32),
#  ('cannib', 32),
#  ('number', 32),
#  ('mount', 32),
#  ('furnish', 32),
#  ('glide', 32),
#  ('proper', 32),
#  ('seek', 32),
#  ('burn', 32),
#  ('henc', 32),
#  ('woe', 32),
#  ('aft', 32),
#  ('coil', 32),
#  ('late', 31),
#  ('anim', 31),
#  ('proceed', 31),
#  ('yard', 31),
#  ('shore', 31),
#  ('hang', 31),
#  ('degre', 31),
#  ('fresh', 31),
#  ('speci', 31),
#  ('steadi', 31),
#  ('gale', 31),
#  ('upper', 31),
#  ('marvel', 31),
#  ('port', 31),
#  ('cold', 31),
#  ('foot', 31),
#  ('shadow', 31),
#  ('soft', 31),
#  ('skull', 31),
#  ('strain', 31),
#  ('father', 31),
#  ('across', 31),
#  ('intens', 31),
#  ('cask', 31),
#  ('steer', 31),
#  ('swift', 30),
#  ('import', 30),
#  ('steel', 30),
#  ('express', 30),
#  ('shake', 30),
#  ('interest', 30),
#  ('jump', 30),
#  ('realli', 30),
#  ('quarter-deck', 30),
#  ('thrust', 30),
#  ('hump', 30),
#  ('wrinkl', 30),
#  ('measur', 30),
#  ('supper', 30),
#  ('anchor', 30),
#  ('descend', 30),
#  ('laugh', 30),
#  ('sideway', 30),
#  ('secret', 30),
#  ('swell', 30),
#  ('lurk', 30),
#  ('leeward', 30),
#  ('coat', 29),
#  ('altogeth', 29),
#  ('hast', 29),
#  ('dive', 29),
#  ('paint', 29),
#  ('front', 29),
#  ('pretti', 29),
#  ('enorm', 29),
#  ('possess', 29),
#  ('lead', 29),
#  ('vain', 29),
#  ('unless', 29),
#  ('astern', 29),
#  ('nay', 29),
#  ('certainli', 29),
#  ('pagan', 29),
#  ('behold', 29),
#  ('sweet', 29),
#  ('accord', 29),
#  ('eleph', 29),
#  ('pole', 29),
#  ('gunwal', 29),
#  ('ancient', 28),
#  ('visit', 28),
#  ('wound', 28),
#  ('fishermen', 28),
#  ('roar', 28),
#  ('cover', 28),
#  ('free', 28),
#  ('rear', 28),
#  ('extrem', 28),
#  ('ad', 28),
#  ('probabl', 28),
#  ('throw', 28),
#  ('tree', 28),
#  ('desir', 28),
#  ('mountain', 28),
#  ('royal', 28),
#  ('meanwhil', 28),
#  ('push', 28),
#  ('spot', 28),
#  ('hung', 28),
#  ('subject', 28),
#  ('chest', 28),
#  ('shout', 28),
#  ('duti', 28),
#  ('rose', 28),
#  ('ring', 28),
#  ('spread', 28),
#  ('whale-boat', 28),
#  ('period', 28),
#  ('latitud', 28),
#  ('parse', 28),
#  ('bird', 27),
#  ('countri', 27),
#  ('equal', 27),
#  ('bright', 27),
#  ('mysteri', 27),
#  ('ti', 27),
#  ('christian', 27),
#  ('isl', 27),
#  ('pace', 27),
#  ('content', 27),
#  ('arriv', 27),
#  ('offer', 27),
#  ('swing', 27),
#  ('wooden', 27),
#  ('blubber', 27),
#  ('lip', 27),
#  ('somewhat', 27),
#  ('kick', 27),
#  ('dream', 27),
#  ('lash', 27),
#  ('fatal', 27),
#  ('figur', 27),
#  ('dare', 27),
#  ('law', 27),
#  ('overboard', 27),
#  ('lock', 27),
#  ('heed', 27),
#  ('spirit', 27),
#  ('wholli', 27),
#  ('doubloon', 27),
#  ('ahead', 27),
#  ('alongsid', 27),
#  ('canal', 27),
#  ('fedallah', 27),
#  ('pick', 26),
#  ('author', 26),
#  ('warm', 26),
#  ('swallow', 26),
#  ('troubl', 26),
#  ('battl', 26),
#  ('smell', 26),
#  ('crack', 26),
#  ('mystic', 26),
#  ('pursuit', 26),
#  ('street', 26),
#  ('nail', 26),
#  ('compass', 26),
#  ('sweep', 26),
#  ('dog', 26),
#  ('eat', 26),
#  ('mutter', 26),
#  ('midnight', 26),
#  ('hair', 26),
#  ('comfort', 26),
#  ('otherwis', 26),
#  ('fight', 26),
#  ('event', 26),
#  ('walk', 26),
#  ('faith', 26),
#  ('delight', 26),
#  ('insert', 26),
#  ('descri', 26),
#  ('son', 26),
#  ('bodili', 26),
#  ('reveal', 26),
#  ('declar', 26),
#  ('herd', 26),
#  ('evinc', 26),
#  ('pain', 25),
#  ('prepar', 25),
#  ('dread', 25),
#  ('thirti', 25),
#  ('attend', 25),
#  ('shoulder', 25),
#  ('seldom', 25),
#  ('thrown', 25),
#  ('forti', 25),
#  ('dutch', 25),
#  ('bound', 25),
#  ('regular', 25),
#  ('wateri', 25),
#  ('distinct', 25),
#  ('cheer', 25),
#  ('perceiv', 25),
#  ('afterward', 25),
#  ('drink', 25),
#  ('blast', 25),
#  ('curs', 25),
#  ('prodigi', 25),
#  ('rememb', 25),
#  ('similar', 25),
#  ('wife', 25),
#  ('owe', 25),
#  ('strip', 25),
#  ('asid', 25),
#  ('twenti', 25),
#  ('season', 25),
#  ('shape', 25),
#  ('squall', 25),
#  ('suppli', 24),
#  ('ignor', 24),
#  ('letter', 24),
#  ('immedi', 24),
#  ('includ', 24),
#  ('glass', 24),
#  ('pleas', 24),
#  ('special', 24),
#  ('hook', 24),
#  ('shroud', 24),
#  ('erect', 24),
#  ('breez', 24),
#  ('crowd', 24),
#  ('travel', 24),
#  ('toil', 24),
#  ('exactli', 24),
#  ('becam', 24),
#  ('beyond', 24),
#  ('fieri', 24),
#  ('repeat', 24),
#  ('base', 24),
#  ('finger', 24),
#  ('hole', 24),
#  ('violent', 24),
#  ('stay', 24),
#  ('squar', 24),
#  ('terribl', 24),
#  ('lamp', 24),
#  ('ran', 24),
#  ('mother', 24),
#  ('pilot', 24),
#  ('blacksmith', 24),
#  ('instead', 24),
#  ('upward', 24),
#  ('prow', 24),
#  ('success', 24),
#  ('billow', 24),
#  ('ask', 24),
#  ('owner', 24),
#  ('strength', 24),
#  ('thyself', 24),
#  ('haul', 24),
#  ('tackl', 24),
#  ('wreck', 24),
#  ('lakeman', 24),
#  ('empti', 23),
#  ('six', 23),
#  ('ponder', 23),
#  ('stretch', 23),
#  ('frequent', 23),
#  ('master', 23),
#  ('globe', 23),
#  ('south', 23),
#  ('refer', 23),
#  ('barb', 23),
#  ('histori', 23),
#  ('lightn', 23),
#  ('send', 23),
#  ('depart', 23),
#  ('hollow', 23),
#  ('beach', 23),
#  ('glori', 23),
#  ('pay', 23),
#  ('ah', 23),
#  ('fate', 23),
#  ('drawn', 23),
#  ('jolli', 23),
#  ('negro', 23),
#  ('howl', 23),
#  ('centr', 23),
#  ('yield', 23),
#  ('handl', 23),
#  ('settl', 23),
#  ('jacket', 23),
#  ('contrast', 23),
#  ('spare', 23),
#  ('flew', 23),
#  ('higher', 23),
#  ('somewher', 23),
#  ('disappear', 23),
#  ('contain', 23),
#  ('hot', 23),
#  ('notic', 23),
#  ('real', 23),
#  ('hidden', 23),
#  ('meantim', 23),
#  ('instantli', 23),
#  ('pile', 23),
#  ('month', 23),
#  ('aliv', 23),
#  ('flesh', 23),
#  ('deadli', 23),
#  ('affair', 23),
#  ('remark', 23),
#  ('occasion', 23),
#  ('catch', 22),
#  ('magnitud', 22),
#  ('french', 22),
#  ('colour', 22),
#  ('stove', 22),
#  ('employ', 22),
#  ('eight', 22),
#  ('surpris', 22),
#  ('town', 22),
#  ('virtu', 22),
#  ('phantom', 22),
#  ('hors', 22),
#  ('piec', 22),
#  ('tall', 22),
#  ('understand', 22),
#  ('avast', 22),
#  ('whisper', 22),
#  ('likewis', 22),
#  ('game', 22),
#  ('palm', 22),
#  ('dri', 22),
#  ('drew', 22),
#  ('profound', 22),
#  ('porpois', 22),
#  ('buri', 22),
#  ('centuri', 22),
#  ('divid', 22),
#  ('flash', 22),
#  ('forg', 22),
#  ('superior', 22),
#  ('loos', 22),
#  ('windward', 22),
#  ('slide', 22),
#  ('log', 22),
#  ('flank', 22),
#  ('exampl', 22),
#  ('attach', 22),
#  ('radney', 22),
#  ('scarc', 21),
#  ('exceed', 21),
#  ('immens', 21),
#  ('holi', 21),
#  ('fail', 21),
#  ('joy', 21),
#  ('hill', 21),
#  ('dim', 21),
#  ('engag', 21),
#  ('everyth', 21),
#  ('lee', 21),
#  ('cool', 21),
#  ('torment', 21),
#  ('drown', 21),
#  ('spar', 21),
#  ('term', 21),
#  ('weari', 21),
#  ('wors', 21),
#  ('shiver', 21),
#  ('england', 21),
#  ('truli', 21),
#  ('downward', 21),
#  ('apart', 21),
#  ('chang', 21),
#  ('bless', 21),
#  ('save', 21),
#  ('eager', 21),
#  ('coward', 21),
#  ('aboard', 21),
#  ('remov', 21),
#  ...]

# %% [markdown]
# One disadvanatage of stemming is that you can end up with non-words.

# %%
porter.stem('remove')
# Out:
# 'remov'

# %% [markdown]
# We might instead try a lemmatizer, like the WordNetLemmatizer from NLTK.

# %%
wnl = WordNetLemmatizer()

# %%
wnl.lemmatize('whales')
# Out:
# 'whale'

# %%
moby_counter = Counter([wnl.lemmatize(x.lower()) for x in regexp_tokenize(moby, r'[-\'\w]+') if x.lower() not in stop_words])

# %%
len(moby_counter)
# Out:
# 16573

# %%
moby_counter.most_common()
# Out:
# [('whale', 1348),
#  ('one', 931),
#  ('like', 584),
#  ('upon', 565),
#  ('ship', 547),
#  ('ahab', 507),
#  ('man', 499),
#  ('ye', 471),
#  ('sea', 471),
#  ('old', 443),
#  ('time', 438),
#  ('boat', 431),
#  ('would', 430),
#  ('though', 384),
#  ('captain', 346),
#  ('yet', 344),
#  ('hand', 332),
#  ('head', 321),
#  ('thing', 320),
#  ('long', 316),
#  ('still', 312),
#  ('said', 305),
#  ('great', 304),
#  ('say', 290),
#  ('two', 289),
#  ('way', 285),
#  ('must', 283),
#  ('seemed', 283),
#  ('last', 277),
#  ('see', 276),
#  ('thou', 271),
#  ('stubb', 255),
#  ('queequeg', 252),
#  ('white', 250),
#  ('little', 249),
#  ('round', 248),
#  ('go', 247),
#  ('day', 243),
#  ('three', 242),
#  ('eye', 238),
#  ('may', 238),
#  ('men', 237),
#  ('sperm', 237),
#  ('water', 236),
#  ('first', 235),
#  ('every', 232),
#  ('come', 232),
#  ('u', 230),
#  ('well', 223),
#  ('much', 223),
#  ('could', 216),
#  ('side', 216),
#  ('look', 212),
#  ('never', 206),
#  ('good', 199),
#  ('starbuck', 198),
#  ('almost', 195),
#  ('ever', 194),
#  ('even', 189),
#  ('part', 189),
#  ('deck', 184),
#  ('thought', 183),
#  ('might', 183),
#  ('chapter', 181),
#  ('away', 180),
#  ('know', 180),
#  ('world', 177),
#  ('made', 177),
#  ('sir', 172),
#  ('pequod', 172),
#  ('god', 171),
#  ('sort', 171),
#  ('among', 167),
#  ('life', 167),
#  ('many', 166),
#  ('seen', 164),
#  ('take', 162),
#  ('back', 161),
#  ('far', 159),
#  ('let', 159),
#  ('crew', 157),
#  ('without', 156),
#  ('oh', 156),
#  ('cried', 156),
#  ('foot', 155),
#  ('line', 154),
#  ('aye', 154),
#  ('make', 151),
#  ('right', 147),
#  ('night', 144),
#  ('think', 142),
#  ('air', 140),
#  ('tell', 138),
#  ('whole', 137),
#  ('harpooneer', 135),
#  ('thus', 132),
#  ('thee', 131),
#  ('came', 130),
#  ('stand', 130),
#  ('soon', 130),
#  ('sailor', 130),
#  ('place', 130),
#  ('small', 124),
#  ('leg', 124),
#  ('till', 123),
#  ('something', 122),
#  ('sail', 121),
#  ('year', 120),
#  ('body', 119),
#  ('arm', 119),
#  ('voyage', 118),
#  ('saw', 117),
#  ('moment', 117),
#  ('heart', 116),
#  ('sight', 116),
#  ('nothing', 115),
#  ('found', 115),
#  ('another', 115),
#  ('towards', 114),
#  ('mate', 114),
#  ('called', 113),
#  ('full', 113),
#  ('whaling', 113),
#  ('poor', 112),
#  ('leviathan', 112),
#  ('fish', 112),
#  ('thy', 112),
#  ('end', 111),
#  ('heard', 110),
#  ('face', 110),
#  ('along', 110),
#  ('flask', 109),
#  ('word', 105),
#  ('give', 104),
#  ('soul', 104),
#  ('harpoon', 103),
#  ('hold', 102),
#  ('high', 101),
#  ('matter', 99),
#  ('get', 99),
#  ('strange', 97),
#  ('went', 97),
#  ('case', 95),
#  ('however', 95),
#  ('shall', 95),
#  ('turn', 95),
#  ('mind', 95),
#  ('sun', 95),
#  ('iron', 93),
#  ('nantucket', 92),
#  ('also', 91),
#  ('whether', 91),
#  ('dead', 91),
#  ('half', 90),
#  ('stood', 90),
#  ('certain', 89),
#  ('wind', 89),
#  ('perhaps', 89),
#  ('indeed', 89),
#  ('order', 88),
#  ('black', 88),
#  ('true', 87),
#  ('whose', 87),
#  ('sometimes', 87),
#  ('ocean', 87),
#  ('seems', 87),
#  ('bow', 87),
#  ('present', 86),
#  ('new', 85),
#  ('seem', 85),
#  ('going', 85),
#  ('light', 85),
#  ('jonah', 84),
#  ('mean', 84),
#  ('tail', 83),
#  ('jaw', 83),
#  ('wild', 83),
#  ('bone', 82),
#  ('point', 82),
#  ('standing', 82),
#  ('moby', 82),
#  ('dick', 82),
#  ('name', 81),
#  ('length', 81),
#  ('land', 81),
#  ('hour', 81),
#  ('known', 80),
#  ('always', 80),
#  ('hard', 80),
#  ('within', 79),
#  ('oil', 79),
#  ('set', 79),
#  ('death', 79),
#  ('young', 79),
#  ('ere', 79),
#  ('large', 78),
#  ('lay', 77),
#  ('instant', 77),
#  ('keep', 77),
#  ('bildad', 77),
#  ('least', 76),
#  ('vessel', 76),
#  ('beneath', 76),
#  ('mr', 76),
#  ('enough', 76),
#  ('put', 76),
#  ('creature', 75),
#  ('shark', 75),
#  ('yes', 75),
#  ('reason', 75),
#  ('bed', 75),
#  ('morning', 75),
#  ('cabin', 75),
#  ('boy', 74),
#  ('done', 74),
#  ('pip', 74),
#  ('feel', 73),
#  ('vast', 73),
#  ('living', 73),
#  ('peleg', 73),
#  ('book', 72),
#  ('work', 72),
#  ('rather', 72),
#  ('often', 72),
#  ('open', 71),
#  ('whalemen', 71),
#  ('deep', 70),
#  ('king', 70),
#  ('near', 70),
#  ('fire', 69),
#  ('cannot', 69),
#  ('lord', 68),
#  ('mouth', 68),
#  ('four', 68),
#  ('devil', 67),
#  ('therefore', 67),
#  ('call', 67),
#  ('general', 67),
#  ('business', 67),
#  ('mark', 67),
#  ('best', 66),
#  ('thousand', 66),
#  ('left', 66),
#  ('turned', 66),
#  ('lower', 66),
#  ('find', 65),
#  ('heaven', 65),
#  ('since', 65),
#  ('together', 64),
#  ('better', 64),
#  ('board', 64),
#  ('lance', 64),
#  ('looked', 64),
#  ('fishery', 64),
#  ('hear', 63),
#  ('savage', 63),
#  ('oar', 63),
#  ('aloft', 62),
#  ('spout', 62),
#  ('run', 62),
#  ('indian', 60),
#  ('second', 60),
#  ('chase', 60),
#  ('st', 60),
#  ('gone', 59),
#  ('wave', 59),
#  ('live', 59),
#  ('hundred', 58),
#  ('form', 58),
#  ('particular', 58),
#  ('fine', 58),
#  ('cry', 58),
#  ('fellow', 57),
#  ('home', 57),
#  ('looking', 57),
#  ('interval', 57),
#  ('gentleman', 57),
#  ('peculiar', 56),
#  ('story', 56),
#  ('dark', 56),
#  ('watch', 56),
#  ('next', 56),
#  ('tashtego', 56),
#  ('voice', 55),
#  ('forward', 55),
#  ('short', 55),
#  ('coffin', 55),
#  ('rope', 55),
#  ('cook', 55),
#  ('seaman', 55),
#  ('stranger', 55),
#  ('entire', 55),
#  ('close', 54),
#  ('stern', 54),
#  ('mast', 54),
#  ('blood', 54),
#  ('bottom', 54),
#  ('curious', 54),
#  ('coming', 53),
#  ('monster', 53),
#  ('sleep', 53),
#  ('less', 53),
#  ('taking', 53),
#  ('sound', 53),
#  ('rest', 53),
#  ('began', 53),
#  ('chance', 52),
#  ('cut', 52),
#  ('slowly', 52),
#  ('turning', 52),
#  ('circumstance', 52),
#  ('craft', 52),
#  ('forth', 52),
#  ('broad', 52),
#  ('fact', 52),
#  ('carpenter', 52),
#  ('view', 51),
#  ('taken', 51),
#  ('ten', 51),
#  ('grand', 51),
#  ('ivory', 51),
#  ('besides', 50),
#  ('behind', 50),
#  ('speak', 50),
#  ('green', 50),
#  ('blow', 50),
#  ('object', 50),
#  ('suddenly', 50),
#  ('mortal', 50),
#  ('sign', 50),
#  ('common', 50),
#  ('nevertheless', 50),
#  ('ground', 50),
#  ('_', 49),
#  ('bear', 49),
#  ('instance', 49),
#  ('took', 49),
#  ('pull', 49),
#  ('island', 48),
#  ('wake', 48),
#  ('english', 48),
#  ('door', 48),
#  ('plank', 48),
#  ('used', 48),
#  ('lost', 47),
#  ('mighty', 47),
#  ('lie', 47),
#  ('told', 47),
#  ('several', 47),
#  ('struck', 47),
#  ('mass', 47),
#  ('kept', 47),
#  ('wonder', 47),
#  ('course', 47),
#  ('earth', 46),
#  ('whatever', 46),
#  ('touching', 46),
#  ('teeth', 46),
#  ('people', 46),
#  ('whaleman', 46),
#  ('else', 46),
#  ('broken', 46),
#  ('room', 46),
#  ('got', 46),
#  ('fast', 46),
#  ('caught', 45),
#  ('mariner', 45),
#  ('sat', 45),
#  ('sure', 45),
#  ('straight', 45),
#  ('mine', 45),
#  ('power', 45),
#  ('queer', 44),
#  ('somehow', 44),
#  ('noble', 44),
#  ('art', 44),
#  ('calm', 44),
#  ('nature', 44),
#  ('coast', 44),
#  ('wide', 44),
#  ('especially', 44),
#  ('running', 44),
#  ('making', 43),
#  ('pipe', 43),
#  ('account', 43),
#  ('purpose', 43),
#  ('knew', 43),
#  ('nigh', 43),
#  ('blue', 43),
#  ('anything', 43),
#  ('rolled', 43),
#  ('brain', 42),
#  ('mere', 42),
#  ('friend', 42),
#  ('hat', 42),
#  ('passed', 42),
#  ('house', 42),
#  ('want', 42),
#  ('em', 42),
#  ('sudden', 42),
#  ('brow', 42),
#  ('aspect', 42),
#  ('wondrous', 42),
#  ('surface', 42),
#  ('alone', 41),
#  ('clear', 41),
#  ('carry', 41),
#  ('distance', 41),
#  ('quite', 41),
#  ('sharp', 41),
#  ('plain', 41),
#  ('felt', 41),
#  ('sky', 41),
#  ('terror', 41),
#  ('either', 40),
#  ('american', 40),
#  ('quick', 40),
#  ('jet', 40),
#  ('forehead', 40),
#  ('ready', 40),
#  ('shipmate', 40),
#  ('saying', 40),
#  ('fluke', 40),
#  ('concerning', 40),
#  ('wood', 40),
#  ('steelkilt', 40),
#  ('others', 39),
#  ('leaving', 39),
#  ('plainly', 39),
#  ('fear', 39),
#  ('lad', 39),
#  ('idea', 39),
#  ('top', 39),
#  ('show', 39),
#  ('skeleton', 39),
#  ('brought', 38),
#  ('doubt', 38),
#  ('fixed', 38),
#  ('around', 38),
#  ('hunter', 38),
#  ('mile', 38),
#  ('manner', 38),
#  ('mast-head', 38),
#  ('single', 38),
#  ('various', 38),
#  ('sailed', 38),
#  ('five', 38),
#  ('help', 38),
#  ('company', 38),
#  ('minute', 38),
#  ('darted', 38),
#  ('gave', 38),
#  ('hope', 38),
#  ('whaler', 38),
#  ('start', 38),
#  ('strike', 37),
#  ('placed', 37),
#  ('bulwark', 37),
#  ('forecastle', 37),
#  ('easy', 37),
#  ('cape', 37),
#  ('famous', 37),
#  ('low', 37),
#  ('suppose', 37),
#  ('ear', 37),
#  ('holding', 37),
#  ('scene', 37),
#  ('human', 37),
#  ('held', 37),
#  ('truth', 37),
#  ('drawing', 37),
#  ('hull', 37),
#  ('daggoo', 37),
#  ('greenland', 36),
#  ('horn', 36),
#  ('pacific', 36),
#  ('ago', 36),
#  ('mad', 36),
#  ('fell', 36),
#  ('peril', 36),
#  ('middle', 36),
#  ('ha', 36),
#  ('unknown', 36),
#  ('seeing', 36),
#  ('third', 36),
#  ('age', 36),
#  ('question', 36),
#  ('circle', 36),
#  ('use', 36),
#  ('given', 36),
#  ('natural', 36),
#  ('strong', 35),
#  ('killed', 35),
#  ('passage', 35),
#  ('previous', 35),
#  ('picture', 35),
#  ('inch', 35),
#  ('table', 35),
#  ('gold', 35),
#  ('helm', 35),
#  ('glance', 35),
#  ('keel', 35),
#  ('nose', 35),
#  ('sailing', 35),
#  ('hammer', 35),
#  ('fifty', 34),
#  ('ashore', 34),
#  ('fisherman', 34),
#  ('person', 34),
#  ('nearly', 34),
#  ('shot', 34),
#  ('feeling', 34),
#  ('officer', 34),
#  ('red', 34),
#  ('wall', 34),
#  ('landlord', 34),
#  ('hammock', 34),
#  ('skin', 34),
#  ('none', 34),
#  ('heavy', 34),
#  ('remained', 34),
#  ('de', 34),
#  ('rolling', 33),
#  ('bulk', 33),
#  ('child', 33),
#  ('bit', 33),
#  ('rigging', 33),
#  ('need', 33),
#  ('act', 33),
#  ('stop', 33),
#  ('fair', 33),
#  ('completely', 33),
#  ('flame', 33),
#  ('hardly', 33),
#  ('substance', 33),
#  ('hint', 33),
#  ('cast', 33),
#  ('fin', 33),
#  ('try', 32),
#  ('rib', 32),
#  ('mast-heads', 32),
#  ('storm', 32),
#  ('chief', 32),
#  ('spring', 32),
#  ('already', 32),
#  ('darkness', 32),
#  ('weather', 32),
#  ('proper', 32),
#  ('hence', 32),
#  ('woe', 32),
#  ('aft', 32),
#  ('rising', 32),
#  ('roll', 31),
#  ('generally', 31),
#  ('yard', 31),
#  ('rock', 31),
#  ('degree', 31),
#  ('specie', 31),
#  ('gale', 31),
#  ('upper', 31),
#  ('drop', 31),
#  ('touch', 31),
#  ('considering', 31),
#  ('port', 31),
#  ('cold', 31),
#  ('visible', 31),
#  ('number', 31),
#  ('skull', 31),
#  ('father', 31),
#  ('across', 31),
#  ('pas', 31),
#  ('except', 31),
#  ('oarsman', 31),
#  ('late', 30),
#  ('shore', 30),
#  ('swimming', 30),
#  ('huge', 30),
#  ('kind', 30),
#  ('steel', 30),
#  ('fresh', 30),
#  ('possible', 30),
#  ('possibly', 30),
#  ('really', 30),
#  ('quarter-deck', 30),
#  ('cannibal', 30),
#  ('supper', 30),
#  ('soft', 30),
#  ('thinking', 30),
#  ('wife', 30),
#  ('carried', 30),
#  ('command', 30),
#  ('die', 30),
#  ('born', 30),
#  ('altogether', 29),
#  ('hast', 29),
#  ('dart', 29),
#  ('motion', 29),
#  ('swim', 29),
#  ('pretty', 29),
#  ('entirely', 29),
#  ('steady', 29),
#  ('smoke', 29),
#  ('vain', 29),
#  ('unless', 29),
#  ('astern', 29),
#  ('nay', 29),
#  ('tossed', 29),
#  ('shadow', 29),
#  ('fancy', 29),
#  ('final', 29),
#  ('certainly', 29),
#  ('pagan', 29),
#  ('sideways', 29),
#  ('read', 29),
#  ('secret', 29),
#  ('suspended', 29),
#  ('cask', 29),
#  ('strangely', 29),
#  ('leeward', 29),
#  ('elephant', 29),
#  ('pole', 29),
#  ('gunwale', 29),
#  ('hoisted', 29),
#  ('ancient', 28),
#  ('play', 28),
#  ('state', 28),
#  ('free', 28),
#  ('front', 28),
#  ('thunder', 28),
#  ('whale-ship', 28),
#  ('meet', 28),
#  ('tree', 28),
#  ('leaning', 28),
#  ('mild', 28),
#  ('royal', 28),
#  ('answer', 28),
#  ('meanwhile', 28),
#  ('hung', 28),
#  ('become', 28),
#  ('chest', 28),
#  ('duty', 28),
#  ('giving', 28),
#  ('rose', 28),
#  ('latitude', 28),
#  ('whiteness', 28),
#  ('parsee', 28),
#  ('coat', 27),
#  ('bird', 27),
#  ('country', 27),
#  ('kill', 27),
#  ('ti', 27),
#  ('finally', 27),
#  ('precisely', 27),
#  ('isle', 27),
#  ('believe', 27),
#  ('started', 27),
#  ('step', 27),
#  ('flying', 27),
#  ('wooden', 27),
#  ('lip', 27),
#  ('somewhat', 27),
#  ('eyeing', 27),
#  ('beat', 27),
#  ('overboard', 27),
#  ('level', 27),
#  ('dropped', 27),
#  ('spirit', 27),
#  ('wholly', 27),
#  ('advance', 27),
#  ('doubloon', 27),
#  ('ahead', 27),
#  ('alongside', 27),
#  ('fedallah', 27),
#  ('received', 26),
#  ('floating', 26),
#  ('enormous', 26),
#  ('pursuit', 26),
#  ('street', 26),
#  ('silent', 26),
#  ('seated', 26),
#  ('considerable', 26),
#  ('honor', 26),
#  ('followed', 26),
#  ('talk', 26),
#  ('midnight', 26),
#  ('subject', 26),
#  ('hair', 26),
#  ('hump', 26),
#  ('getting', 26),
#  ('rise', 26),
#  ('break', 26),
#  ('otherwise', 26),
#  ('anchor', 26),
#  ('event', 26),
#  ('law', 26),
#  ('sweet', 26),
#  ('son', 26),
#  ('bearing', 26),
#  ('bodily', 26),
#  ('pointed', 26),
#  ('spread', 26),
#  ('according', 26),
#  ('whale-boat', 26),
#  ('blubber', 26),
#  ('love', 25),
#  ('learned', 25),
#  ('thirty', 25),
#  ('battle', 25),
#  ('breath', 25),
#  ('seldom', 25),
#  ('thrown', 25),
#  ('bright', 25),
#  ('forty', 25),
#  ('christian', 25),
#  ('dutch', 25),
#  ('watery', 25),
#  ('content', 25),
#  ('compass', 25),
#  ('thick', 25),
#  ('afterwards', 25),
#  ('added', 25),
#  ('cause', 25),
#  ('similar', 25),
#  ('cutting', 25),
#  ('aside', 25),
#  ('complete', 25),
#  ('escape', 25),
#  ('twenty', 25),
#  ('squall', 25),
#  ('hunt', 25),
#  ('blind', 25),
#  ('warm', 24),
#  ('grow', 24),
#  ('glass', 24),
#  ('respect', 24),
#  ('regarded', 24),
#  ('different', 24),
#  ('regular', 24),
#  ('mountain', 24),
#  ('exactly', 24),
#  ('following', 24),
#  ('became', 24),
#  ('beyond', 24),
#  ('spot', 24),
#  ('fiery', 24),
#  ('swift', 24),
#  ('finger', 24),
#  ('hole', 24),
#  ('lamp', 24),
#  ('ran', 24),
#  ('figure', 24),
#  ('owing', 24),
#  ('commanded', 24),
#  ('blacksmith', 24),
#  ('instead', 24),
#  ('prow', 24),
#  ('billow', 24),
#  ('hinted', 24),
#  ('owner', 24),
#  ('strength', 24),
#  ('direction', 24),
#  ('herd', 24),
#  ('thyself', 24),
#  ('remains', 24),
#  ('tackle', 24),
#  ('pulling', 24),
#  ('lakeman', 24),
#  ('letter', 23),
#  ('six', 23),
#  ('shoulder', 23),
#  ('globe', 23),
#  ('smell', 23),
#  ('south', 23),
#  ('history', 23),
#  ('rear', 23),
#  ('lightning', 23),
#  ('bound', 23),
#  ('breeze', 23),
#  ('begin', 23),
#  ('ah', 23),
#  ('dog', 23),
#  ('drawn', 23),
#  ('jolly', 23),
#  ('row', 23),
#  ('negro', 23),
#  ('centre', 23),
#  ('drive', 23),
#  ('jacket', 23),
#  ('flew', 23),
#  ('higher', 23),
#  ('somewhere', 23),
#  ('hot', 23),
#  ('passing', 23),
#  ('real', 23),
#  ('hidden', 23),
#  ('meantime', 23),
#  ('mother', 23),
#  ('instantly', 23),
#  ('month', 23),
#  ('alive', 23),
#  ('pilot', 23),
#  ('flesh', 23),
#  ('burst', 23),
#  ('fit', 23),
#  ('speaking', 23),
#  ('consider', 23),
#  ('affair', 23),
#  ('sink', 23),
#  ('remain', 23),
#  ('master', 22),
#  ('magnitude', 22),
#  ('french', 22),
#  ('answered', 22),
#  ('stove', 22),
#  ('striking', 22),
#  ('eight', 22),
#  ('town', 22),
#  ('virtue', 22),
#  ('hollow', 22),
#  ('phantom', 22),
#  ('glory', 22),
#  ('horse', 22),
#  ('fate', 22),
#  ('piece', 22),
#  ('tall', 22),
#  ('wonderful', 22),
#  ('filled', 22),
#  ('avast', 22),
#  ('likewise', 22),
#  ('terrible', 22),
#  ('game', 22),
#  ('drew', 22),
#  ('porpoise', 22),
#  ('deadly', 22),
#  ('century', 22),
#  ('descried', 22),
#  ('nantucketer', 22),
#  ('windward', 22),
#  ('dashed', 22),
#  ('log', 22),
#  ('gazing', 22),
#  ('example', 22),
#  ('radney', 22),
#  ('animal', 21),
#  ('sing', 21),
#  ('hill', 21),
#  ('shake', 21),
#  ('lee', 21),
#  ('leaf', 21),
#  ('beach', 21),
#  ('meaning', 21),
#  ('spar', 21),
#  ('formed', 21),
#  ('term', 21),
#  ('original', 21),
#  ('sitting', 21),
#  ('worse', 21),
#  ('repeated', 21),
#  ('truly', 21),
#  ('seat', 21),
#  ('spare', 21),
#  ('fight', 21),
#  ('coward', 21),
#  ('aboard', 21),
#  ('quickly', 21),
#  ('solitary', 21),
#  ('lady', 21),
#  ('seek', 21),
#  ('lofty', 21),
#  ('base', 21),
#  ('swell', 21),
#  ('season', 21),
#  ('shape', 21),
#  ('hailed', 21),
#  ('period', 21),
#  ('invested', 21),
#  ('evinced', 21),
#  ('attached', 21),
#  ('tub', 21),
#  ('beheld', 21),
#  ('empty', 20),
#  ('gabriel', 20),
#  ('former', 20),
#  ('holy', 20),
#  ('queen', 20),
#  ('swam', 20),
#  ('everything', 20),
#  ('interest', 20),
#  ('directly', 20),
#  ('vicinity', 20),
#  ('ishmael', 20),
#  ('distant', 20),
#  ('separate', 20),
#  ('pay', 20),
#  ('swung', 20),
#  ('quarter', 20),
#  ('dim', 20),
#  ('drink', 20),
#  ('england', 20),
#  ('gigantic', 20),
#  ('space', 20),
#  ('fain', 20),
#  ('raised', 20),
#  ('sleeping', 20),
#  ('floor', 20),
#  ('neck', 20),
#  ('palm', 20),
#  ('follow', 20),
#  ('outer', 20),
#  ('past', 20),
#  ('laugh', 20),
#  ('profound', 20),
#  ('silence', 20),
#  ('slightest', 20),
#  ('native', 20),
#  ('woman', 20),
#  ('died', 20),
#  ('depth', 20),
#  ('ring', 20),
#  ('fall', 20),
#  ('float', 20),
#  ('laid', 20),
#  ('delight', 20),
#  ('hanging', 20),
#  ('commander', 20),
#  ('moreover', 20),
#  ('foe', 20),
#  ('loose', 20),
#  ('dost', 20),
#  ('knife', 20),
#  ('windlass', 20),
#  ('encounter', 20),
#  ('000', 20),
#  ('dignity', 20),
#  ('lowering', 20),
#  ('flank', 20),
#  ('golden', 20),
#  ('cruising', 20),
#  ('lowered', 20),
#  ('dat', 20),
#  ('pale', 19),
#  ('fly', 19),
#  ('modern', 19),
#  ('bring', 19),
#  ('important', 19),
#  ('largest', 19),
#  ('ordinary', 19),
#  ('spermaceti', 19),
#  ('element', 19),
#  ('colour', 19),
#  ('atlantic', 19),
#  ('pointing', 19),
#  ('rush', 19),
#  ('comrade', 19),
#  ('trunk', 19),
#  ('deeper', 19),
#  ('fowl', 19),
#  ('difference', 19),
#  ('presented', 19),
#  ('presently', 19),
#  ('church', 19),
#  ('thrust', 19),
#  ('rate', 19),
#  ('height', 19),
#  ('sake', 19),
#  ('met', 19),
#  ('beginning', 19),
#  ('yellow', 19),
#  ('square', 19),
#  ('concluded', 19),
#  ('smoking', 19),
#  ('precise', 19),
#  ('awful', 19),
#  ('drag', 19),
#  ('hunted', 19),
#  ('stuff', 19),
#  ('brave', 19),
#  ('eternal', 19),
#  ('upwards', 19),
#  ('swiftly', 19),
#  ('reached', 19),
#  ('chiefly', 19),
#  ('rod', 19),
#  ('merely', 19),
#  ('eh', 19),
#  ('horizon', 19),
#  ('fool', 19),
#  ('ghost', 19),
#  ('rapidly', 19),
#  ('vapor', 19),
#  ('bucket', 19),
#  ('pump', 19),
#  ('whereas', 18),
#  ('prophet', 18),
#  ('wound', 18),
#  ('forced', 18),
#  ('belly', 18),
#  ('stroke', 18),
#  ('observed', 18),
#  ('shroud', 18),
#  ...]

# %% [markdown]
# Finally, let's look at the distribution of words.

# %%
plt.figure(figsize = (10,6))
plt.hist(moby_counter.values(), bins = 50, edgecolor = 'black')
plt.xlabel('Number of Appearances')
plt.ylabel('Number of Words');

# %%
pd.Series(moby_counter.values()).describe()
# Out:
# count    16573.000000
# mean         6.551077
# std         26.025339
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max       1348.000000
# dtype: float64

# %% [markdown]
# If we want a fun way to visualize the most frequent words in the text, we can use a word cloud.

# %%
# %conda install wordcloud
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: \
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cython-3.2.4               |  py313haa24f5a_0         3.3 MB
#     wordcloud-1.9.5            |  py313h03d0aa3_0         178 KB
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cython             pkgs/main/osx-arm64::cython-3.2.4-py313haa24f5a_0
#   wordcloud          pkgs/main/osx-arm64::wordcloud-1.9.5-py313h03d0aa3_0
#
#
#
# Downloading and Extracting Packages:
# cython-3.2.4         | 3.3 MB    |                                       |   0%
# wordcloud-1.9.5      | 178 KB    |                                       |   0%
# cython-3.2.4         | 3.3 MB    | 1                                     |   0%
# wordcloud-1.9.5      | 178 KB    | ##################################### | 100%
#
#
# donearing transaction: \
# donefying transaction: /
# Executing transactiondone
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud()

wc.generate_from_frequencies(moby_counter)
plt.figure(figsize = (10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off");
